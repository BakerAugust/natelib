# %%
import os 
os.chdir('../../')

# %%
import torch
from torch.utils.data import DataLoader, SubsetRandomSampler
from torch.nn.functional import cross_entropy
from torchvision import datasets, transforms

# %%
BATCH_SIZE = 256
RANDOM_SEED = 88
VALIDATION_FRACTION = 0.2 # pct of training data to use in validation

torch.manual_seed(RANDOM_SEED)

# %%
train_transformer = transforms.Compose([
    transforms.Resize((40,40)),
    transforms.RandomCrop((32, 32)),
    transforms.ToTensor(),
    transforms.Normalize((0.5,0.5,0.5), (0.5,0.5,0.5))
])

test_transformer = transforms.Compose([
    transforms.Resize((40,40)),
    transforms.CenterCrop((32, 32)),
    transforms.ToTensor(),
    transforms.Normalize((0.5,0.5,0.5), (0.5,0.5,0.5))
])

train_data = datasets.CIFAR10(root='data', train=True, transform=train_transformer, download=True)
test_data = datasets.CIFAR10(root='data', train=False, transform=test_transformer, download=True)

n_valid = int(VALIDATION_FRACTION * 50000)
train_idxs = torch.arange(0, 50000 - n_valid)
valid_idxs = torch.arange(50000 - n_valid, 50000)

train_dataloader = DataLoader(
    train_data, 
    batch_size=BATCH_SIZE, 
    sampler=SubsetRandomSampler(train_idxs)
    )

valid_dataloader = DataLoader(
    train_data, 
    batch_size=BATCH_SIZE, 
    sampler=SubsetRandomSampler(valid_idxs)
    )

test_dataloader = DataLoader(test_data, batch_size=BATCH_SIZE)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
class CNN(torch.nn.Module):
    '''
    Convolutional Neural Net
    '''
    def __init__(self, n_classes: int):
        super().__init__()

        self.n_classes = n_classes
        self.layers = torch.nn.Sequential(
            torch.nn.Conv2d(3, 32, kernel_size=3, stride=2, padding=1),
            torch.nn.BatchNorm2d(32),
            torch.nn.LeakyReLU(0.1, inplace=True),
            #
            torch.nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
            torch.nn.BatchNorm2d(64),
            torch.nn.LeakyReLU(0.1, inplace=True),
            #
            torch.nn.Conv2d(64, 64, kernel_size=3, stride=2, padding=1),
            torch.nn.BatchNorm2d(64),
            torch.nn.LeakyReLU(0.1, inplace=True),
            #
            torch.nn.Flatten(),
            torch.nn.Linear(4096, 128),
            torch.nn.BatchNorm1d(128),
            torch.nn.LeakyReLU(0.1, inplace=True),
            torch.nn.Dropout(0.5),
            #
            torch.nn.Linear(128, n_classes),
                )
    
    def forward(self, x):
        logits = self.layers(x)
        return logits

    def fit(
        self,
        train_dataloader: DataLoader,
        valid_dataloader: DataLoader,
        learning_rate: float,
        epochs: int,
        verbose=False,
    ) -> None:

        optim = torch.optim.Adam(self.parameters(), lr=learning_rate)
        scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
            optim,
            factor=0.1,
            mode='max',
            verbose=True)
                
        self.train()

        for e in range(epochs):
            correct, n_examples = 0, 0

            for batch_idx, (x, y) in enumerate(train_dataloader):
                logits = self(x)
                loss = cross_entropy(logits, y)
                optim.zero_grad()

                loss.backward()
                optim.step()

                if verbose:
                    with torch.no_grad():
                        print(
                            f"epoch:{e:.0f}, batch:{batch_idx:.0f}. Loss={loss.item():.3f}"
                        )
                        _, yhat = torch.max(logits, dim=1)
                        correct += torch.sum(yhat == y)
                        n_examples += yhat.size(0)
            
            train_accuracy = correct / n_examples

            # calculate validation accuracy
            self.eval()
            correct, n_examples = 0, 0
            for x, y in valid_dataloader:
                logits = self(x)
                _, yhat = torch.max(logits, dim=1)
                correct += torch.sum(yhat == y)
                n_examples += yhat.size(0)
                valid_accuracy = correct / n_examples

            # scheduler
            scheduler.step(valid_accuracy)


            # Print train and valid accuracy on each epoch
            if verbose:
                print(
                    f"epoch:{e:.0f} over, training_acc={train_accuracy.item():.3f}, 'valid_acc={valid_accuracy.item():.3f}"
                    )

# %%
cnn = CNN(n_classes=10)

# %%
cnn.fit(train_dataloader, valid_dataloader, 0.1, epochs=50, verbose=True)
# Out:
# epoch:0, batch:0. Loss=3.401
# epoch:0, batch:1. Loss=2.717
# epoch:0, batch:2. Loss=2.390
# epoch:0, batch:3. Loss=2.175
# epoch:0, batch:4. Loss=2.191
# epoch:0, batch:5. Loss=2.121
# epoch:0, batch:6. Loss=2.006
# epoch:0, batch:7. Loss=1.851
# epoch:0, batch:8. Loss=1.910
# epoch:0, batch:9. Loss=1.947
# epoch:0, batch:10. Loss=1.884
# epoch:0, batch:11. Loss=1.751
# epoch:0, batch:12. Loss=1.927
# epoch:0, batch:13. Loss=1.807
# epoch:0, batch:14. Loss=1.686
# epoch:0, batch:15. Loss=1.775
# epoch:0, batch:16. Loss=1.640
# epoch:0, batch:17. Loss=1.678
# epoch:0, batch:18. Loss=1.562
# epoch:0, batch:19. Loss=1.692
# epoch:0, batch:20. Loss=1.693
# epoch:0, batch:21. Loss=1.610
# epoch:0, batch:22. Loss=1.589
# epoch:0, batch:23. Loss=1.589
# epoch:0, batch:24. Loss=1.581
# epoch:0, batch:25. Loss=1.548
# epoch:0, batch:26. Loss=1.417
# epoch:0, batch:27. Loss=1.705
# epoch:0, batch:28. Loss=1.403
# epoch:0, batch:29. Loss=1.548
# epoch:0, batch:30. Loss=1.527
# epoch:0, batch:31. Loss=1.486
# epoch:0, batch:32. Loss=1.525
# epoch:0, batch:33. Loss=1.426
# epoch:0, batch:34. Loss=1.418
# epoch:0, batch:35. Loss=1.536
# epoch:0, batch:36. Loss=1.680
# epoch:0, batch:37. Loss=1.527
# epoch:0, batch:38. Loss=1.506
# epoch:0, batch:39. Loss=1.489
# epoch:0, batch:40. Loss=1.459
# epoch:0, batch:41. Loss=1.576
# epoch:0, batch:42. Loss=1.399
# epoch:0, batch:43. Loss=1.568
# epoch:0, batch:44. Loss=1.565
# epoch:0, batch:45. Loss=1.614
# epoch:0, batch:46. Loss=1.605
# epoch:0, batch:47. Loss=1.549
# epoch:0, batch:48. Loss=1.432
# epoch:0, batch:49. Loss=1.500
# epoch:0, batch:50. Loss=1.414
# epoch:0, batch:51. Loss=1.581
# epoch:0, batch:52. Loss=1.659
# epoch:0, batch:53. Loss=1.569
# epoch:0, batch:54. Loss=1.533
# epoch:0, batch:55. Loss=1.553
# epoch:0, batch:56. Loss=1.519
# epoch:0, batch:57. Loss=1.367
# epoch:0, batch:58. Loss=1.396
# epoch:0, batch:59. Loss=1.496
# epoch:0, batch:60. Loss=1.525
# epoch:0, batch:61. Loss=1.386
# epoch:0, batch:62. Loss=1.549
# epoch:0, batch:63. Loss=1.417
# epoch:0, batch:64. Loss=1.507
# epoch:0, batch:65. Loss=1.432
# epoch:0, batch:66. Loss=1.464
# epoch:0, batch:67. Loss=1.471
# epoch:0, batch:68. Loss=1.564
# epoch:0, batch:69. Loss=1.576
# epoch:0, batch:70. Loss=1.511
# epoch:0, batch:71. Loss=1.546
# epoch:0, batch:72. Loss=1.460
# epoch:0, batch:73. Loss=1.529
# epoch:0, batch:74. Loss=1.490
# epoch:0, batch:75. Loss=1.381
# epoch:0, batch:76. Loss=1.504
# epoch:0, batch:77. Loss=1.482
# epoch:0, batch:78. Loss=1.407
# epoch:0, batch:79. Loss=1.369
# epoch:0, batch:80. Loss=1.498
# epoch:0, batch:81. Loss=1.424
# epoch:0, batch:82. Loss=1.341
# epoch:0, batch:83. Loss=1.362
# epoch:0, batch:84. Loss=1.485
# epoch:0, batch:85. Loss=1.370
# epoch:0, batch:86. Loss=1.376
# epoch:0, batch:87. Loss=1.365
# epoch:0, batch:88. Loss=1.558
# epoch:0, batch:89. Loss=1.635
# epoch:0, batch:90. Loss=1.493
# epoch:0, batch:91. Loss=1.525
# epoch:0, batch:92. Loss=1.430
# epoch:0, batch:93. Loss=1.446
# epoch:0, batch:94. Loss=1.525
# epoch:0, batch:95. Loss=1.561
# epoch:0, batch:96. Loss=1.459
# epoch:0, batch:97. Loss=1.377
# epoch:0, batch:98. Loss=1.565
# epoch:0, batch:99. Loss=1.373
# epoch:0, batch:100. Loss=1.427
# epoch:0, batch:101. Loss=1.341
# epoch:0, batch:102. Loss=1.391
# epoch:0, batch:103. Loss=1.470
# epoch:0, batch:104. Loss=1.429
# epoch:0, batch:105. Loss=1.385
# epoch:0, batch:106. Loss=1.505
# epoch:0, batch:107. Loss=1.414
# epoch:0, batch:108. Loss=1.341
# epoch:0, batch:109. Loss=1.487
# epoch:0, batch:110. Loss=1.285
# epoch:0, batch:111. Loss=1.464
# epoch:0, batch:112. Loss=1.420
# epoch:0, batch:113. Loss=1.344
# epoch:0, batch:114. Loss=1.491
# epoch:0, batch:115. Loss=1.246
# epoch:0, batch:116. Loss=1.465
# epoch:0, batch:117. Loss=1.449
# epoch:0, batch:118. Loss=1.347
# epoch:0, batch:119. Loss=1.408
# epoch:0, batch:120. Loss=1.416
# epoch:0, batch:121. Loss=1.345
# epoch:0, batch:122. Loss=1.373
# epoch:0, batch:123. Loss=1.356
# epoch:0, batch:124. Loss=1.456
# epoch:0, batch:125. Loss=1.391
# epoch:0, batch:126. Loss=1.426
# epoch:0, batch:127. Loss=1.448
# epoch:0, batch:128. Loss=1.480
# epoch:0, batch:129. Loss=1.397
# epoch:0, batch:130. Loss=1.395
# epoch:0, batch:131. Loss=1.424
# epoch:0, batch:132. Loss=1.385
# epoch:0, batch:133. Loss=1.479
# epoch:0, batch:134. Loss=1.520
# epoch:0, batch:135. Loss=1.351
# epoch:0, batch:136. Loss=1.498
# epoch:0, batch:137. Loss=1.338
# epoch:0, batch:138. Loss=1.394
# epoch:0, batch:139. Loss=1.306
# epoch:0, batch:140. Loss=1.579
# epoch:0, batch:141. Loss=1.487
# epoch:0, batch:142. Loss=1.424
# epoch:0, batch:143. Loss=1.428
# epoch:0, batch:144. Loss=1.336
# epoch:0, batch:145. Loss=1.390
# epoch:0, batch:146. Loss=1.467
# epoch:0, batch:147. Loss=1.480
# epoch:0, batch:148. Loss=1.553
# epoch:0, batch:149. Loss=1.648
# epoch:0, batch:150. Loss=1.459
# epoch:0, batch:151. Loss=1.451
# epoch:0, batch:152. Loss=1.487
# epoch:0, batch:153. Loss=1.383
# epoch:0, batch:154. Loss=1.396
# epoch:0, batch:155. Loss=1.302
# epoch:0, batch:156. Loss=1.403
# epoch:0 over, training_acc=0.456, 'valid_acc=0.540
# epoch:1, batch:0. Loss=1.284
# epoch:1, batch:1. Loss=1.582
# epoch:1, batch:2. Loss=1.702
# epoch:1, batch:3. Loss=1.500
# epoch:1, batch:4. Loss=1.522
# epoch:1, batch:5. Loss=1.418
# epoch:1, batch:6. Loss=1.435
# epoch:1, batch:7. Loss=1.525
# epoch:1, batch:8. Loss=1.474
# epoch:1, batch:9. Loss=1.307
# epoch:1, batch:10. Loss=1.366
# epoch:1, batch:11. Loss=1.518
# epoch:1, batch:12. Loss=1.342
# epoch:1, batch:13. Loss=1.425
# epoch:1, batch:14. Loss=1.348
# epoch:1, batch:15. Loss=1.366
# epoch:1, batch:16. Loss=1.396
# epoch:1, batch:17. Loss=1.301
# epoch:1, batch:18. Loss=1.195
# epoch:1, batch:19. Loss=1.329
# epoch:1, batch:20. Loss=1.273
# epoch:1, batch:21. Loss=1.252
# epoch:1, batch:22. Loss=1.281
# epoch:1, batch:23. Loss=1.253
# epoch:1, batch:24. Loss=1.226
# epoch:1, batch:25. Loss=1.372
# epoch:1, batch:26. Loss=1.322
# epoch:1, batch:27. Loss=1.289
# epoch:1, batch:28. Loss=1.278
# epoch:1, batch:29. Loss=1.247
# epoch:1, batch:30. Loss=1.480
# epoch:1, batch:31. Loss=1.266
# epoch:1, batch:32. Loss=1.380
# epoch:1, batch:33. Loss=1.254
# epoch:1, batch:34. Loss=1.319
# epoch:1, batch:35. Loss=1.309
# epoch:1, batch:36. Loss=1.227
# epoch:1, batch:37. Loss=1.278
# epoch:1, batch:38. Loss=1.306
# epoch:1, batch:39. Loss=1.311
# epoch:1, batch:40. Loss=1.371
# epoch:1, batch:41. Loss=1.159
# epoch:1, batch:42. Loss=1.306
# epoch:1, batch:43. Loss=1.358
# epoch:1, batch:44. Loss=1.079
# epoch:1, batch:45. Loss=1.282
# epoch:1, batch:46. Loss=1.099
# epoch:1, batch:47. Loss=1.269
# epoch:1, batch:48. Loss=1.344
# epoch:1, batch:49. Loss=1.243
# epoch:1, batch:50. Loss=1.385
# epoch:1, batch:51. Loss=1.112
# epoch:1, batch:52. Loss=1.304
# epoch:1, batch:53. Loss=1.418
# epoch:1, batch:54. Loss=1.177
# epoch:1, batch:55. Loss=1.198
# epoch:1, batch:56. Loss=1.226
# epoch:1, batch:57. Loss=1.201
# epoch:1, batch:58. Loss=1.163
# epoch:1, batch:59. Loss=1.236
# epoch:1, batch:60. Loss=1.145
# epoch:1, batch:61. Loss=1.246
# epoch:1, batch:62. Loss=1.246
# epoch:1, batch:63. Loss=1.181
# epoch:1, batch:64. Loss=1.049
# epoch:1, batch:65. Loss=1.127
# epoch:1, batch:66. Loss=1.066
# epoch:1, batch:67. Loss=1.360
# epoch:1, batch:68. Loss=1.393
# epoch:1, batch:69. Loss=1.027
# epoch:1, batch:70. Loss=1.162
# epoch:1, batch:71. Loss=1.108
# epoch:1, batch:72. Loss=1.128
# epoch:1, batch:73. Loss=1.291
# epoch:1, batch:74. Loss=1.273
# epoch:1, batch:75. Loss=1.121
# epoch:1, batch:76. Loss=1.191
# epoch:1, batch:77. Loss=1.226
# epoch:1, batch:78. Loss=1.141
# epoch:1, batch:79. Loss=1.181
# epoch:1, batch:80. Loss=1.261
# epoch:1, batch:81. Loss=1.187
# epoch:1, batch:82. Loss=1.112
# epoch:1, batch:83. Loss=1.239
# epoch:1, batch:84. Loss=1.235
# epoch:1, batch:85. Loss=1.186
# epoch:1, batch:86. Loss=1.121
# epoch:1, batch:87. Loss=1.174
# epoch:1, batch:88. Loss=1.078
# epoch:1, batch:89. Loss=1.017
# epoch:1, batch:90. Loss=1.059
# epoch:1, batch:91. Loss=1.025
# epoch:1, batch:92. Loss=1.086
# epoch:1, batch:93. Loss=1.346
# epoch:1, batch:94. Loss=1.182
# epoch:1, batch:95. Loss=1.037
# epoch:1, batch:96. Loss=1.268
# epoch:1, batch:97. Loss=1.168
# epoch:1, batch:98. Loss=1.279
# epoch:1, batch:99. Loss=1.208
# epoch:1, batch:100. Loss=1.150
# epoch:1, batch:101. Loss=1.133
# epoch:1, batch:102. Loss=1.344
# epoch:1, batch:103. Loss=1.290
# epoch:1, batch:104. Loss=1.232
# epoch:1, batch:105. Loss=1.195
# epoch:1, batch:106. Loss=1.256
# epoch:1, batch:107. Loss=1.364
# epoch:1, batch:108. Loss=1.239
# epoch:1, batch:109. Loss=1.150
# epoch:1, batch:110. Loss=1.137
# epoch:1, batch:111. Loss=1.223
# epoch:1, batch:112. Loss=1.214
# epoch:1, batch:113. Loss=1.131
# epoch:1, batch:114. Loss=1.180
# epoch:1, batch:115. Loss=1.141
# epoch:1, batch:116. Loss=1.015
# epoch:1, batch:117. Loss=1.193
# epoch:1, batch:118. Loss=1.038
# epoch:1, batch:119. Loss=1.081
# epoch:1, batch:120. Loss=1.064
# epoch:1, batch:121. Loss=1.262
# epoch:1, batch:122. Loss=1.187
# epoch:1, batch:123. Loss=1.129
# epoch:1, batch:124. Loss=1.123
# epoch:1, batch:125. Loss=1.258
# epoch:1, batch:126. Loss=1.161
# epoch:1, batch:127. Loss=1.142
# epoch:1, batch:128. Loss=1.141
# epoch:1, batch:129. Loss=1.223
# epoch:1, batch:130. Loss=1.056
# epoch:1, batch:131. Loss=1.290
# epoch:1, batch:132. Loss=1.135
# epoch:1, batch:133. Loss=1.241
# epoch:1, batch:134. Loss=1.231
# epoch:1, batch:135. Loss=1.320
# epoch:1, batch:136. Loss=1.338
# epoch:1, batch:137. Loss=1.228
# epoch:1, batch:138. Loss=1.112
# epoch:1, batch:139. Loss=1.256
# epoch:1, batch:140. Loss=1.145
# epoch:1, batch:141. Loss=1.287
# epoch:1, batch:142. Loss=1.175
# epoch:1, batch:143. Loss=1.233
# epoch:1, batch:144. Loss=1.144
# epoch:1, batch:145. Loss=1.275
# epoch:1, batch:146. Loss=1.116
# epoch:1, batch:147. Loss=1.239
# epoch:1, batch:148. Loss=1.290
# epoch:1, batch:149. Loss=1.192
# epoch:1, batch:150. Loss=1.217
# epoch:1, batch:151. Loss=1.157
# epoch:1, batch:152. Loss=1.149
# epoch:1, batch:153. Loss=1.208
# epoch:1, batch:154. Loss=1.157
# epoch:1, batch:155. Loss=1.141
# epoch:1, batch:156. Loss=1.181
# epoch:1 over, training_acc=0.557, 'valid_acc=0.558
# epoch:2, batch:0. Loss=1.388
# epoch:2, batch:1. Loss=1.184
# epoch:2, batch:2. Loss=1.237
# epoch:2, batch:3. Loss=1.025
# epoch:2, batch:4. Loss=1.204
# epoch:2, batch:5. Loss=1.191
# epoch:2, batch:6. Loss=1.369
# epoch:2, batch:7. Loss=1.103
# epoch:2, batch:8. Loss=1.265
# epoch:2, batch:9. Loss=1.146
# epoch:2, batch:10. Loss=1.204
# epoch:2, batch:11. Loss=1.170
# epoch:2, batch:12. Loss=1.253
# epoch:2, batch:13. Loss=1.064
# epoch:2, batch:14. Loss=1.185
# epoch:2, batch:15. Loss=1.165
# epoch:2, batch:16. Loss=1.156
# epoch:2, batch:17. Loss=1.232
# epoch:2, batch:18. Loss=1.028
# epoch:2, batch:19. Loss=1.101
# epoch:2, batch:20. Loss=1.110
# epoch:2, batch:21. Loss=1.107
# epoch:2, batch:22. Loss=1.313
# epoch:2, batch:23. Loss=1.314
# epoch:2, batch:24. Loss=1.079
# epoch:2, batch:25. Loss=1.084
# epoch:2, batch:26. Loss=1.046
# epoch:2, batch:27. Loss=1.241
# epoch:2, batch:28. Loss=1.035
# epoch:2, batch:29. Loss=1.203
# epoch:2, batch:30. Loss=1.213
# epoch:2, batch:31. Loss=1.056
# epoch:2, batch:32. Loss=1.224
# epoch:2, batch:33. Loss=1.263
# epoch:2, batch:34. Loss=1.064
# epoch:2, batch:35. Loss=1.209
# epoch:2, batch:36. Loss=1.120
# epoch:2, batch:37. Loss=1.145
# epoch:2, batch:38. Loss=1.258
# epoch:2, batch:39. Loss=1.262
# epoch:2, batch:40. Loss=1.150
# epoch:2, batch:41. Loss=1.124
# epoch:2, batch:42. Loss=1.309
# epoch:2, batch:43. Loss=1.117
# epoch:2, batch:44. Loss=1.068
# epoch:2, batch:45. Loss=1.161
# epoch:2, batch:46. Loss=1.187
# epoch:2, batch:47. Loss=1.198
# epoch:2, batch:48. Loss=1.035
# epoch:2, batch:49. Loss=1.199
# epoch:2, batch:50. Loss=1.098
# epoch:2, batch:51. Loss=1.193
# epoch:2, batch:52. Loss=1.161
# epoch:2, batch:53. Loss=1.146
# epoch:2, batch:54. Loss=1.210
# epoch:2, batch:55. Loss=1.071
# epoch:2, batch:56. Loss=1.155
# epoch:2, batch:57. Loss=1.158
# epoch:2, batch:58. Loss=1.196
# epoch:2, batch:59. Loss=1.130
# epoch:2, batch:60. Loss=1.040
# epoch:2, batch:61. Loss=1.113
# epoch:2, batch:62. Loss=1.101
# epoch:2, batch:63. Loss=1.159
# epoch:2, batch:64. Loss=1.082
# epoch:2, batch:65. Loss=1.156
# epoch:2, batch:66. Loss=1.206
# epoch:2, batch:67. Loss=1.099
# epoch:2, batch:68. Loss=1.128
# epoch:2, batch:69. Loss=1.172
# epoch:2, batch:70. Loss=1.208
# epoch:2, batch:71. Loss=1.067
# epoch:2, batch:72. Loss=1.190
# epoch:2, batch:73. Loss=1.176
# epoch:2, batch:74. Loss=1.153
# epoch:2, batch:75. Loss=1.279
# epoch:2, batch:76. Loss=1.354
# epoch:2, batch:77. Loss=1.111
# epoch:2, batch:78. Loss=1.342
# epoch:2, batch:79. Loss=1.133
# epoch:2, batch:80. Loss=1.104
# epoch:2, batch:81. Loss=1.058
# epoch:2, batch:82. Loss=1.267
# epoch:2, batch:83. Loss=1.200
# epoch:2, batch:84. Loss=1.051
# epoch:2, batch:85. Loss=1.126
# epoch:2, batch:86. Loss=1.073
# epoch:2, batch:87. Loss=1.217
# epoch:2, batch:88. Loss=1.129
# epoch:2, batch:89. Loss=1.171
# epoch:2, batch:90. Loss=1.089
# epoch:2, batch:91. Loss=1.242
# epoch:2, batch:92. Loss=1.115
# epoch:2, batch:93. Loss=1.258
# epoch:2, batch:94. Loss=1.103
# epoch:2, batch:95. Loss=1.196
# epoch:2, batch:96. Loss=1.042
# epoch:2, batch:97. Loss=1.136
# epoch:2, batch:98. Loss=1.186
# epoch:2, batch:99. Loss=1.200
# epoch:2, batch:100. Loss=1.071
# epoch:2, batch:101. Loss=1.228
# epoch:2, batch:102. Loss=1.269
# epoch:2, batch:103. Loss=1.061
# epoch:2, batch:104. Loss=1.127
# epoch:2, batch:105. Loss=1.138
# epoch:2, batch:106. Loss=1.014
# epoch:2, batch:107. Loss=1.166
# epoch:2, batch:108. Loss=1.022
# epoch:2, batch:109. Loss=1.151
# epoch:2, batch:110. Loss=1.162
# epoch:2, batch:111. Loss=1.015
# epoch:2, batch:112. Loss=1.015
# epoch:2, batch:113. Loss=1.167
# epoch:2, batch:114. Loss=1.081
# epoch:2, batch:115. Loss=1.088
# epoch:2, batch:116. Loss=1.165
# epoch:2, batch:117. Loss=1.177
# epoch:2, batch:118. Loss=1.095
# epoch:2, batch:119. Loss=0.974
# epoch:2, batch:120. Loss=1.141
# epoch:2, batch:121. Loss=1.069
# epoch:2, batch:122. Loss=1.084
# epoch:2, batch:123. Loss=1.167
# epoch:2, batch:124. Loss=1.003
# epoch:2, batch:125. Loss=1.049
# epoch:2, batch:126. Loss=1.055
# epoch:2, batch:127. Loss=1.068
# epoch:2, batch:128. Loss=1.157
# epoch:2, batch:129. Loss=1.031
# epoch:2, batch:130. Loss=1.100
# epoch:2, batch:131. Loss=1.120
# epoch:2, batch:132. Loss=1.071
# epoch:2, batch:133. Loss=0.960
# epoch:2, batch:134. Loss=1.117
# epoch:2, batch:135. Loss=1.072
# epoch:2, batch:136. Loss=1.148
# epoch:2, batch:137. Loss=1.132
# epoch:2, batch:138. Loss=1.066
# epoch:2, batch:139. Loss=1.223
# epoch:2, batch:140. Loss=1.238
# epoch:2, batch:141. Loss=1.138
# epoch:2, batch:142. Loss=1.144
# epoch:2, batch:143. Loss=1.049
# epoch:2, batch:144. Loss=1.138
# epoch:2, batch:145. Loss=1.037
# epoch:2, batch:146. Loss=1.033
# epoch:2, batch:147. Loss=1.144
# epoch:2, batch:148. Loss=1.061
# epoch:2, batch:149. Loss=1.126
# epoch:2, batch:150. Loss=1.133
# epoch:2, batch:151. Loss=1.103
# epoch:2, batch:152. Loss=1.092
# epoch:2, batch:153. Loss=1.087
# epoch:2, batch:154. Loss=1.083
# epoch:2, batch:155. Loss=1.139
# epoch:2, batch:156. Loss=0.998
# epoch:2 over, training_acc=0.591, 'valid_acc=0.579
# epoch:3, batch:0. Loss=1.088
# epoch:3, batch:1. Loss=1.260
# epoch:3, batch:2. Loss=1.140
# epoch:3, batch:3. Loss=1.093
# epoch:3, batch:4. Loss=1.067
# epoch:3, batch:5. Loss=1.318
# epoch:3, batch:6. Loss=1.212
# epoch:3, batch:7. Loss=1.130
# epoch:3, batch:8. Loss=1.093
# epoch:3, batch:9. Loss=1.064
# epoch:3, batch:10. Loss=1.304
# epoch:3, batch:11. Loss=1.343
# epoch:3, batch:12. Loss=1.134
# epoch:3, batch:13. Loss=1.120
# epoch:3, batch:14. Loss=1.101
# epoch:3, batch:15. Loss=1.178
# epoch:3, batch:16. Loss=1.262
# epoch:3, batch:17. Loss=1.178
# epoch:3, batch:18. Loss=1.166
# epoch:3, batch:19. Loss=1.191
# epoch:3, batch:20. Loss=1.044
# epoch:3, batch:21. Loss=1.119
# epoch:3, batch:22. Loss=1.057
# epoch:3, batch:23. Loss=1.175
# epoch:3, batch:24. Loss=1.191
# epoch:3, batch:25. Loss=1.040
# epoch:3, batch:26. Loss=1.072
# epoch:3, batch:27. Loss=1.204
# epoch:3, batch:28. Loss=1.181
# epoch:3, batch:29. Loss=1.110
# epoch:3, batch:30. Loss=0.997
# epoch:3, batch:31. Loss=1.057
# epoch:3, batch:32. Loss=1.034
# epoch:3, batch:33. Loss=1.050
# epoch:3, batch:34. Loss=1.042
# epoch:3, batch:35. Loss=1.060
# epoch:3, batch:36. Loss=1.049
# epoch:3, batch:37. Loss=1.047
# epoch:3, batch:38. Loss=1.191
# epoch:3, batch:39. Loss=1.131
# epoch:3, batch:40. Loss=0.955
# epoch:3, batch:41. Loss=1.075
# epoch:3, batch:42. Loss=1.147
# epoch:3, batch:43. Loss=1.098
# epoch:3, batch:44. Loss=1.067
# epoch:3, batch:45. Loss=1.148
# epoch:3, batch:46. Loss=1.034
# epoch:3, batch:47. Loss=1.148
# epoch:3, batch:48. Loss=1.161
# epoch:3, batch:49. Loss=1.039
# epoch:3, batch:50. Loss=1.239
# epoch:3, batch:51. Loss=1.072
# epoch:3, batch:52. Loss=1.070
# epoch:3, batch:53. Loss=1.056
# epoch:3, batch:54. Loss=1.138
# epoch:3, batch:55. Loss=1.073
# epoch:3, batch:56. Loss=1.018
# epoch:3, batch:57. Loss=1.018
# epoch:3, batch:58. Loss=1.183
# epoch:3, batch:59. Loss=1.084
# epoch:3, batch:60. Loss=1.011
# epoch:3, batch:61. Loss=1.122
# epoch:3, batch:62. Loss=1.118
# epoch:3, batch:63. Loss=1.035
# epoch:3, batch:64. Loss=1.216
# epoch:3, batch:65. Loss=1.104
# epoch:3, batch:66. Loss=1.160
# epoch:3, batch:67. Loss=0.847
# epoch:3, batch:68. Loss=1.091
# epoch:3, batch:69. Loss=1.080
# epoch:3, batch:70. Loss=1.024
# epoch:3, batch:71. Loss=1.272
# epoch:3, batch:72. Loss=1.217
# epoch:3, batch:73. Loss=1.236
# epoch:3, batch:74. Loss=1.173
# epoch:3, batch:75. Loss=1.004
# epoch:3, batch:76. Loss=1.030
# epoch:3, batch:77. Loss=0.964
# epoch:3, batch:78. Loss=1.109
# epoch:3, batch:79. Loss=1.164
# epoch:3, batch:80. Loss=1.102
# epoch:3, batch:81. Loss=1.085
# epoch:3, batch:82. Loss=1.119
# epoch:3, batch:83. Loss=1.187
# epoch:3, batch:84. Loss=1.124
# epoch:3, batch:85. Loss=1.011
# epoch:3, batch:86. Loss=1.044
# epoch:3, batch:87. Loss=1.099
# epoch:3, batch:88. Loss=1.100
# epoch:3, batch:89. Loss=1.022
# epoch:3, batch:90. Loss=1.078
# epoch:3, batch:91. Loss=1.190
# epoch:3, batch:92. Loss=1.128
# epoch:3, batch:93. Loss=1.116
# epoch:3, batch:94. Loss=1.297
# epoch:3, batch:95. Loss=1.071
# epoch:3, batch:96. Loss=1.130
# epoch:3, batch:97. Loss=1.183
# epoch:3, batch:98. Loss=1.157
# epoch:3, batch:99. Loss=1.122
# epoch:3, batch:100. Loss=1.134
# epoch:3, batch:101. Loss=1.278
# epoch:3, batch:102. Loss=1.219
# epoch:3, batch:103. Loss=1.157
# epoch:3, batch:104. Loss=1.143
# epoch:3, batch:105. Loss=1.111
# epoch:3, batch:106. Loss=1.112
# epoch:3, batch:107. Loss=1.066
# epoch:3, batch:108. Loss=1.219
# epoch:3, batch:109. Loss=1.160
# epoch:3, batch:110. Loss=1.058
# epoch:3, batch:111. Loss=1.112
# epoch:3, batch:112. Loss=1.213
# epoch:3, batch:113. Loss=1.088
# epoch:3, batch:114. Loss=1.092
# epoch:3, batch:115. Loss=1.167
# epoch:3, batch:116. Loss=1.015
# epoch:3, batch:117. Loss=1.222
# epoch:3, batch:118. Loss=1.172
# epoch:3, batch:119. Loss=1.220
# epoch:3, batch:120. Loss=1.068
# epoch:3, batch:121. Loss=1.056
# epoch:3, batch:122. Loss=0.952
# epoch:3, batch:123. Loss=0.987
# epoch:3, batch:124. Loss=0.983
# epoch:3, batch:125. Loss=1.118
# epoch:3, batch:126. Loss=1.079
# epoch:3, batch:127. Loss=1.056
# epoch:3, batch:128. Loss=1.150
# epoch:3, batch:129. Loss=1.026
# epoch:3, batch:130. Loss=1.125
# epoch:3, batch:131. Loss=1.020
# epoch:3, batch:132. Loss=1.121
# epoch:3, batch:133. Loss=1.168
# epoch:3, batch:134. Loss=1.033
# epoch:3, batch:135. Loss=1.079
# epoch:3, batch:136. Loss=1.056
# epoch:3, batch:137. Loss=1.009
# epoch:3, batch:138. Loss=1.027
# epoch:3, batch:139. Loss=1.075
# epoch:3, batch:140. Loss=1.126
# epoch:3, batch:141. Loss=1.134
# epoch:3, batch:142. Loss=1.136
# epoch:3, batch:143. Loss=1.170
# epoch:3, batch:144. Loss=1.074
# epoch:3, batch:145. Loss=1.107
# epoch:3, batch:146. Loss=1.216
# epoch:3, batch:147. Loss=1.139
# epoch:3, batch:148. Loss=1.054
# epoch:3, batch:149. Loss=0.957
# epoch:3, batch:150. Loss=1.156
# epoch:3, batch:151. Loss=0.969
# epoch:3, batch:152. Loss=1.127
# epoch:3, batch:153. Loss=1.145
# epoch:3, batch:154. Loss=1.198
# epoch:3, batch:155. Loss=0.995
# epoch:3, batch:156. Loss=1.028
# epoch:3 over, training_acc=0.608, 'valid_acc=0.603
# epoch:4, batch:0. Loss=1.162
# epoch:4, batch:1. Loss=1.169
# epoch:4, batch:2. Loss=1.053
# epoch:4, batch:3. Loss=1.000
# epoch:4, batch:4. Loss=1.159
# epoch:4, batch:5. Loss=0.979
# epoch:4, batch:6. Loss=1.099
# epoch:4, batch:7. Loss=1.064
# epoch:4, batch:8. Loss=1.094
# epoch:4, batch:9. Loss=1.025
# epoch:4, batch:10. Loss=1.179
# epoch:4, batch:11. Loss=1.231
# epoch:4, batch:12. Loss=1.212
# epoch:4, batch:13. Loss=1.043
# epoch:4, batch:14. Loss=1.064
# epoch:4, batch:15. Loss=1.055
# epoch:4, batch:16. Loss=1.304
# epoch:4, batch:17. Loss=1.037
# epoch:4, batch:18. Loss=1.108
# epoch:4, batch:19. Loss=0.966
# epoch:4, batch:20. Loss=1.138
# epoch:4, batch:21. Loss=1.119
# epoch:4, batch:22. Loss=0.985
# epoch:4, batch:23. Loss=1.121
# epoch:4, batch:24. Loss=1.001
# epoch:4, batch:25. Loss=1.052
# epoch:4, batch:26. Loss=1.133
# epoch:4, batch:27. Loss=1.134
# epoch:4, batch:28. Loss=1.092
# epoch:4, batch:29. Loss=0.983
# epoch:4, batch:30. Loss=1.063
# epoch:4, batch:31. Loss=1.168
# epoch:4, batch:32. Loss=1.102
# epoch:4, batch:33. Loss=1.021
# epoch:4, batch:34. Loss=1.095
# epoch:4, batch:35. Loss=1.119
# epoch:4, batch:36. Loss=1.143
# epoch:4, batch:37. Loss=1.180
# epoch:4, batch:38. Loss=1.087
# epoch:4, batch:39. Loss=1.087
# epoch:4, batch:40. Loss=1.131
# epoch:4, batch:41. Loss=1.092
# epoch:4, batch:42. Loss=1.197
# epoch:4, batch:43. Loss=1.099
# epoch:4, batch:44. Loss=1.065
# epoch:4, batch:45. Loss=1.106
# epoch:4, batch:46. Loss=1.097
# epoch:4, batch:47. Loss=0.996
# epoch:4, batch:48. Loss=1.048
# epoch:4, batch:49. Loss=1.005
# epoch:4, batch:50. Loss=1.048
# epoch:4, batch:51. Loss=0.935
# epoch:4, batch:52. Loss=1.077
# epoch:4, batch:53. Loss=1.185
# epoch:4, batch:54. Loss=1.194
# epoch:4, batch:55. Loss=1.013
# epoch:4, batch:56. Loss=1.069
# epoch:4, batch:57. Loss=1.153
# epoch:4, batch:58. Loss=1.074
# epoch:4, batch:59. Loss=0.935
# epoch:4, batch:60. Loss=1.139
# epoch:4, batch:61. Loss=1.048
# epoch:4, batch:62. Loss=1.121
# epoch:4, batch:63. Loss=1.064
# epoch:4, batch:64. Loss=0.921
# epoch:4, batch:65. Loss=1.044
# epoch:4, batch:66. Loss=1.106
# epoch:4, batch:67. Loss=1.029
# epoch:4, batch:68. Loss=1.055
# epoch:4, batch:69. Loss=1.020
# epoch:4, batch:70. Loss=1.049
# epoch:4, batch:71. Loss=1.175
# epoch:4, batch:72. Loss=1.211
# epoch:4, batch:73. Loss=1.031
# epoch:4, batch:74. Loss=1.047
# epoch:4, batch:75. Loss=1.022
# epoch:4, batch:76. Loss=1.214
# epoch:4, batch:77. Loss=1.182
# epoch:4, batch:78. Loss=0.992
# epoch:4, batch:79. Loss=1.212
# epoch:4, batch:80. Loss=1.144
# epoch:4, batch:81. Loss=1.074
# epoch:4, batch:82. Loss=1.046
# epoch:4, batch:83. Loss=1.034
# epoch:4, batch:84. Loss=1.072
# epoch:4, batch:85. Loss=1.129
# epoch:4, batch:86. Loss=1.087
# epoch:4, batch:87. Loss=1.130
# epoch:4, batch:88. Loss=1.100
# epoch:4, batch:89. Loss=1.163
# epoch:4, batch:90. Loss=1.072
# epoch:4, batch:91. Loss=1.042
# epoch:4, batch:92. Loss=1.060
# epoch:4, batch:93. Loss=1.112
# epoch:4, batch:94. Loss=1.060
# epoch:4, batch:95. Loss=1.133
# epoch:4, batch:96. Loss=1.066
# epoch:4, batch:97. Loss=0.955
# epoch:4, batch:98. Loss=1.151
# epoch:4, batch:99. Loss=1.122
# epoch:4, batch:100. Loss=1.035
# epoch:4, batch:101. Loss=1.116
# epoch:4, batch:102. Loss=1.134
# epoch:4, batch:103. Loss=1.161
# epoch:4, batch:104. Loss=1.063
# epoch:4, batch:105. Loss=1.105
# epoch:4, batch:106. Loss=1.083
# epoch:4, batch:107. Loss=1.253
# epoch:4, batch:108. Loss=1.109
# epoch:4, batch:109. Loss=1.060
# epoch:4, batch:110. Loss=1.231
# epoch:4, batch:111. Loss=1.114
# epoch:4, batch:112. Loss=0.929
# epoch:4, batch:113. Loss=1.081
# epoch:4, batch:114. Loss=1.076
# epoch:4, batch:115. Loss=0.947
# epoch:4, batch:116. Loss=1.005
# epoch:4, batch:117. Loss=0.990
# epoch:4, batch:118. Loss=1.108
# epoch:4, batch:119. Loss=1.009
# epoch:4, batch:120. Loss=1.052
# epoch:4, batch:121. Loss=1.096
# epoch:4, batch:122. Loss=1.187
# epoch:4, batch:123. Loss=1.049
# epoch:4, batch:124. Loss=1.050
# epoch:4, batch:125. Loss=1.111
# epoch:4, batch:126. Loss=1.167
# epoch:4, batch:127. Loss=1.023
# epoch:4, batch:128. Loss=1.118
# epoch:4, batch:129. Loss=1.135
# epoch:4, batch:130. Loss=1.036
# epoch:4, batch:131. Loss=1.021
# epoch:4, batch:132. Loss=1.142
# epoch:4, batch:133. Loss=0.924
# epoch:4, batch:134. Loss=1.148
# epoch:4, batch:135. Loss=0.971
# epoch:4, batch:136. Loss=1.067
# epoch:4, batch:137. Loss=1.021
# epoch:4, batch:138. Loss=1.106
# epoch:4, batch:139. Loss=1.078
# epoch:4, batch:140. Loss=1.053
# epoch:4, batch:141. Loss=1.091
# epoch:4, batch:142. Loss=1.130
# epoch:4, batch:143. Loss=1.084
# epoch:4, batch:144. Loss=1.077
# epoch:4, batch:145. Loss=0.970
# epoch:4, batch:146. Loss=0.989
# epoch:4, batch:147. Loss=1.191
# epoch:4, batch:148. Loss=0.977
# epoch:4, batch:149. Loss=1.189
# epoch:4, batch:150. Loss=1.185
# epoch:4, batch:151. Loss=1.048
# epoch:4, batch:152. Loss=1.085
# epoch:4, batch:153. Loss=1.074
# epoch:4, batch:154. Loss=1.193
# epoch:4, batch:155. Loss=1.298
# epoch:4, batch:156. Loss=1.345
# epoch:4 over, training_acc=0.614, 'valid_acc=0.609
# epoch:5, batch:0. Loss=1.017
# epoch:5, batch:1. Loss=1.036
# epoch:5, batch:2. Loss=1.031
# epoch:5, batch:3. Loss=0.910
# epoch:5, batch:4. Loss=1.026
# epoch:5, batch:5. Loss=1.101
# epoch:5, batch:6. Loss=0.933
# epoch:5, batch:7. Loss=1.025
# epoch:5, batch:8. Loss=1.117
# epoch:5, batch:9. Loss=1.149
# epoch:5, batch:10. Loss=1.065
# epoch:5, batch:11. Loss=1.060
# epoch:5, batch:12. Loss=1.023
# epoch:5, batch:13. Loss=1.051
# epoch:5, batch:14. Loss=1.013
# epoch:5, batch:15. Loss=1.020
# epoch:5, batch:16. Loss=1.127
# epoch:5, batch:17. Loss=1.060
# epoch:5, batch:18. Loss=1.009
# epoch:5, batch:19. Loss=0.970
# epoch:5, batch:20. Loss=0.989
# epoch:5, batch:21. Loss=1.005
# epoch:5, batch:22. Loss=0.950
# epoch:5, batch:23. Loss=0.965
# epoch:5, batch:24. Loss=1.126
# epoch:5, batch:25. Loss=0.940
# epoch:5, batch:26. Loss=1.143
# epoch:5, batch:27. Loss=1.034
# epoch:5, batch:28. Loss=1.093
# epoch:5, batch:29. Loss=0.971
# epoch:5, batch:30. Loss=1.063
# epoch:5, batch:31. Loss=0.944
# epoch:5, batch:32. Loss=1.147
# epoch:5, batch:33. Loss=1.097
# epoch:5, batch:34. Loss=1.037
# epoch:5, batch:35. Loss=1.130
# epoch:5, batch:36. Loss=1.140
# epoch:5, batch:37. Loss=1.359
# epoch:5, batch:38. Loss=1.074
# epoch:5, batch:39. Loss=1.023
# epoch:5, batch:40. Loss=1.163
# epoch:5, batch:41. Loss=1.153
# epoch:5, batch:42. Loss=0.964
# epoch:5, batch:43. Loss=1.048
# epoch:5, batch:44. Loss=1.152
# epoch:5, batch:45. Loss=1.218
# epoch:5, batch:46. Loss=0.957
# epoch:5, batch:47. Loss=1.240
# epoch:5, batch:48. Loss=1.193
# epoch:5, batch:49. Loss=1.086
# epoch:5, batch:50. Loss=1.042
# epoch:5, batch:51. Loss=1.078
# epoch:5, batch:52. Loss=1.087
# epoch:5, batch:53. Loss=1.116
# epoch:5, batch:54. Loss=1.106
# epoch:5, batch:55. Loss=1.069
# epoch:5, batch:56. Loss=1.018
# epoch:5, batch:57. Loss=1.152
# epoch:5, batch:58. Loss=1.098
# epoch:5, batch:59. Loss=1.044
# epoch:5, batch:60. Loss=1.086
# epoch:5, batch:61. Loss=1.081
# epoch:5, batch:62. Loss=0.969
# epoch:5, batch:63. Loss=0.923
# epoch:5, batch:64. Loss=1.083
# epoch:5, batch:65. Loss=0.977
# epoch:5, batch:66. Loss=1.003
# epoch:5, batch:67. Loss=1.165
# epoch:5, batch:68. Loss=1.033
# epoch:5, batch:69. Loss=1.002
# epoch:5, batch:70. Loss=1.100
# epoch:5, batch:71. Loss=1.045
# epoch:5, batch:72. Loss=1.108
# epoch:5, batch:73. Loss=0.993
# epoch:5, batch:74. Loss=1.128
# epoch:5, batch:75. Loss=1.051
# epoch:5, batch:76. Loss=1.100
# epoch:5, batch:77. Loss=1.077
# epoch:5, batch:78. Loss=1.270
# epoch:5, batch:79. Loss=1.083
# epoch:5, batch:80. Loss=1.061
# epoch:5, batch:81. Loss=1.124
# epoch:5, batch:82. Loss=1.132
# epoch:5, batch:83. Loss=0.955
# epoch:5, batch:84. Loss=0.958
# epoch:5, batch:85. Loss=1.127
# epoch:5, batch:86. Loss=1.084
# epoch:5, batch:87. Loss=0.998
# epoch:5, batch:88. Loss=1.072
# epoch:5, batch:89. Loss=1.129
# epoch:5, batch:90. Loss=0.949
# epoch:5, batch:91. Loss=1.126
# epoch:5, batch:92. Loss=1.089
# epoch:5, batch:93. Loss=1.065
# epoch:5, batch:94. Loss=0.971
# epoch:5, batch:95. Loss=1.157
# epoch:5, batch:96. Loss=1.107
# epoch:5, batch:97. Loss=0.994
# epoch:5, batch:98. Loss=1.046
# epoch:5, batch:99. Loss=1.108
# epoch:5, batch:100. Loss=1.025
# epoch:5, batch:101. Loss=1.012
# epoch:5, batch:102. Loss=1.079
# epoch:5, batch:103. Loss=1.058
# epoch:5, batch:104. Loss=1.122
# epoch:5, batch:105. Loss=1.131
# epoch:5, batch:106. Loss=1.012
# epoch:5, batch:107. Loss=1.082
# epoch:5, batch:108. Loss=1.107
# epoch:5, batch:109. Loss=1.128
# epoch:5, batch:110. Loss=1.169
# epoch:5, batch:111. Loss=1.046
# epoch:5, batch:112. Loss=1.078
# epoch:5, batch:113. Loss=1.127
# epoch:5, batch:114. Loss=1.065
# epoch:5, batch:115. Loss=1.146
# epoch:5, batch:116. Loss=1.010
# epoch:5, batch:117. Loss=1.052
# epoch:5, batch:118. Loss=1.054
# epoch:5, batch:119. Loss=1.164
# epoch:5, batch:120. Loss=1.053
# epoch:5, batch:121. Loss=1.013
# epoch:5, batch:122. Loss=1.080
# epoch:5, batch:123. Loss=0.972
# epoch:5, batch:124. Loss=1.047
# epoch:5, batch:125. Loss=0.989
# epoch:5, batch:126. Loss=0.988
# epoch:5, batch:127. Loss=0.976
# epoch:5, batch:128. Loss=1.067
# epoch:5, batch:129. Loss=1.152
# epoch:5, batch:130. Loss=1.107
# epoch:5, batch:131. Loss=1.011
# epoch:5, batch:132. Loss=0.997
# epoch:5, batch:133. Loss=1.166
# epoch:5, batch:134. Loss=1.025
# epoch:5, batch:135. Loss=1.038
# epoch:5, batch:136. Loss=1.081
# epoch:5, batch:137. Loss=0.998
# epoch:5, batch:138. Loss=1.113
# epoch:5, batch:139. Loss=0.973
# epoch:5, batch:140. Loss=1.166
# epoch:5, batch:141. Loss=1.134
# epoch:5, batch:142. Loss=1.137
# epoch:5, batch:143. Loss=1.046
# epoch:5, batch:144. Loss=1.241
# epoch:5, batch:145. Loss=1.197
# epoch:5, batch:146. Loss=1.126
# epoch:5, batch:147. Loss=1.211
# epoch:5, batch:148. Loss=1.058
# epoch:5, batch:149. Loss=1.158
# epoch:5, batch:150. Loss=1.125
# epoch:5, batch:151. Loss=0.989
# epoch:5, batch:152. Loss=1.113
# epoch:5, batch:153. Loss=1.073
# epoch:5, batch:154. Loss=1.078
# epoch:5, batch:155. Loss=1.042
# epoch:5, batch:156. Loss=1.154
# epoch:5 over, training_acc=0.619, 'valid_acc=0.602
# epoch:6, batch:0. Loss=1.052
# epoch:6, batch:1. Loss=1.185
# epoch:6, batch:2. Loss=1.026
# epoch:6, batch:3. Loss=0.919
# epoch:6, batch:4. Loss=1.137
# epoch:6, batch:5. Loss=1.101
# epoch:6, batch:6. Loss=1.135
# epoch:6, batch:7. Loss=1.048
# epoch:6, batch:8. Loss=0.941
# epoch:6, batch:9. Loss=0.996
# epoch:6, batch:10. Loss=1.244
# epoch:6, batch:11. Loss=1.064
# epoch:6, batch:12. Loss=0.927
# epoch:6, batch:13. Loss=0.985
# epoch:6, batch:14. Loss=1.093
# epoch:6, batch:15. Loss=1.174
# epoch:6, batch:16. Loss=1.039
# epoch:6, batch:17. Loss=1.001
# epoch:6, batch:18. Loss=1.118
# epoch:6, batch:19. Loss=0.970
# epoch:6, batch:20. Loss=0.986
# epoch:6, batch:21. Loss=1.083
# epoch:6, batch:22. Loss=0.955
# epoch:6, batch:23. Loss=1.048
# epoch:6, batch:24. Loss=0.890
# epoch:6, batch:25. Loss=1.075
# epoch:6, batch:26. Loss=1.023
# epoch:6, batch:27. Loss=1.028
# epoch:6, batch:28. Loss=0.999
# epoch:6, batch:29. Loss=1.070
# epoch:6, batch:30. Loss=1.032
# epoch:6, batch:31. Loss=1.049
# epoch:6, batch:32. Loss=1.108
# epoch:6, batch:33. Loss=1.025
# epoch:6, batch:34. Loss=1.052
# epoch:6, batch:35. Loss=0.984
# epoch:6, batch:36. Loss=1.039
# epoch:6, batch:37. Loss=1.141
# epoch:6, batch:38. Loss=1.113
# epoch:6, batch:39. Loss=0.967
# epoch:6, batch:40. Loss=0.902
# epoch:6, batch:41. Loss=1.018
# epoch:6, batch:42. Loss=1.018
# epoch:6, batch:43. Loss=1.088
# epoch:6, batch:44. Loss=0.933
# epoch:6, batch:45. Loss=1.075
# epoch:6, batch:46. Loss=1.089
# epoch:6, batch:47. Loss=0.957
# epoch:6, batch:48. Loss=0.980
# epoch:6, batch:49. Loss=0.942
# epoch:6, batch:50. Loss=0.981
# epoch:6, batch:51. Loss=1.043
# epoch:6, batch:52. Loss=1.008
# epoch:6, batch:53. Loss=1.060
# epoch:6, batch:54. Loss=1.036
# epoch:6, batch:55. Loss=1.140
# epoch:6, batch:56. Loss=0.888
# epoch:6, batch:57. Loss=1.073
# epoch:6, batch:58. Loss=0.925
# epoch:6, batch:59. Loss=0.932
# epoch:6, batch:60. Loss=1.182
# epoch:6, batch:61. Loss=1.020
# epoch:6, batch:62. Loss=0.996
# epoch:6, batch:63. Loss=0.965
# epoch:6, batch:64. Loss=1.130
# epoch:6, batch:65. Loss=1.007
# epoch:6, batch:66. Loss=1.003
# epoch:6, batch:67. Loss=0.972
# epoch:6, batch:68. Loss=1.066
# epoch:6, batch:69. Loss=1.143
# epoch:6, batch:70. Loss=1.031
# epoch:6, batch:71. Loss=1.007
# epoch:6, batch:72. Loss=1.033
# epoch:6, batch:73. Loss=1.152
# epoch:6, batch:74. Loss=0.927
# epoch:6, batch:75. Loss=1.128
# epoch:6, batch:76. Loss=0.937
# epoch:6, batch:77. Loss=1.148
# epoch:6, batch:78. Loss=1.098
# epoch:6, batch:79. Loss=1.039
# epoch:6, batch:80. Loss=1.098
# epoch:6, batch:81. Loss=0.983
# epoch:6, batch:82. Loss=1.112
# epoch:6, batch:83. Loss=1.025
# epoch:6, batch:84. Loss=1.026
# epoch:6, batch:85. Loss=1.139
# epoch:6, batch:86. Loss=1.023
# epoch:6, batch:87. Loss=1.104
# epoch:6, batch:88. Loss=1.178
# epoch:6, batch:89. Loss=0.876
# epoch:6, batch:90. Loss=1.128
# epoch:6, batch:91. Loss=1.048
# epoch:6, batch:92. Loss=1.015
# epoch:6, batch:93. Loss=0.972
# epoch:6, batch:94. Loss=0.925
# epoch:6, batch:95. Loss=0.997
# epoch:6, batch:96. Loss=1.098
# epoch:6, batch:97. Loss=1.021
# epoch:6, batch:98. Loss=1.003
# epoch:6, batch:99. Loss=1.005
# epoch:6, batch:100. Loss=1.002
# epoch:6, batch:101. Loss=1.055
# epoch:6, batch:102. Loss=0.947
# epoch:6, batch:103. Loss=1.059
# epoch:6, batch:104. Loss=1.160
# epoch:6, batch:105. Loss=0.974
# epoch:6, batch:106. Loss=1.113
# epoch:6, batch:107. Loss=0.952
# epoch:6, batch:108. Loss=0.940
# epoch:6, batch:109. Loss=1.144
# epoch:6, batch:110. Loss=1.047
# epoch:6, batch:111. Loss=1.160
# epoch:6, batch:112. Loss=1.025
# epoch:6, batch:113. Loss=1.136
# epoch:6, batch:114. Loss=1.029
# epoch:6, batch:115. Loss=1.031
# epoch:6, batch:116. Loss=0.941
# epoch:6, batch:117. Loss=0.906
# epoch:6, batch:118. Loss=1.013
# epoch:6, batch:119. Loss=1.056
# epoch:6, batch:120. Loss=1.010
# epoch:6, batch:121. Loss=1.155
# epoch:6, batch:122. Loss=0.970
# epoch:6, batch:123. Loss=1.038
# epoch:6, batch:124. Loss=0.987
# epoch:6, batch:125. Loss=1.096
# epoch:6, batch:126. Loss=0.928
# epoch:6, batch:127. Loss=1.019
# epoch:6, batch:128. Loss=1.013
# epoch:6, batch:129. Loss=0.963
# epoch:6, batch:130. Loss=1.167
# epoch:6, batch:131. Loss=1.078
# epoch:6, batch:132. Loss=0.968
# epoch:6, batch:133. Loss=1.111
# epoch:6, batch:134. Loss=1.047
# epoch:6, batch:135. Loss=0.957
# epoch:6, batch:136. Loss=1.178
# epoch:6, batch:137. Loss=1.175
# epoch:6, batch:138. Loss=1.045
# epoch:6, batch:139. Loss=1.104
# epoch:6, batch:140. Loss=1.204
# epoch:6, batch:141. Loss=1.149
# epoch:6, batch:142. Loss=1.071
# epoch:6, batch:143. Loss=1.206
# epoch:6, batch:144. Loss=0.952
# epoch:6, batch:145. Loss=1.079
# epoch:6, batch:146. Loss=1.035
# epoch:6, batch:147. Loss=0.950
# epoch:6, batch:148. Loss=1.020
# epoch:6, batch:149. Loss=1.013
# epoch:6, batch:150. Loss=0.998
# epoch:6, batch:151. Loss=1.004
# epoch:6, batch:152. Loss=1.081
# epoch:6, batch:153. Loss=0.911
# epoch:6, batch:154. Loss=1.024
# epoch:6, batch:155. Loss=1.001
# epoch:6, batch:156. Loss=1.209
# epoch:6 over, training_acc=0.631, 'valid_acc=0.631
# epoch:7, batch:0. Loss=0.893
# epoch:7, batch:1. Loss=1.083
# epoch:7, batch:2. Loss=1.012
# epoch:7, batch:3. Loss=0.939
# epoch:7, batch:4. Loss=1.056
# epoch:7, batch:5. Loss=0.965
# epoch:7, batch:6. Loss=0.974
# epoch:7, batch:7. Loss=0.890
# epoch:7, batch:8. Loss=1.005
# epoch:7, batch:9. Loss=0.972
# epoch:7, batch:10. Loss=1.009
# epoch:7, batch:11. Loss=0.954
# epoch:7, batch:12. Loss=1.043
# epoch:7, batch:13. Loss=0.998
# epoch:7, batch:14. Loss=1.197
# epoch:7, batch:15. Loss=1.067
# epoch:7, batch:16. Loss=1.011
# epoch:7, batch:17. Loss=1.071
# epoch:7, batch:18. Loss=0.995
# epoch:7, batch:19. Loss=1.026
# epoch:7, batch:20. Loss=1.015
# epoch:7, batch:21. Loss=0.904
# epoch:7, batch:22. Loss=0.942
# epoch:7, batch:23. Loss=0.998
# epoch:7, batch:24. Loss=1.208
# epoch:7, batch:25. Loss=0.914
# epoch:7, batch:26. Loss=1.052
# epoch:7, batch:27. Loss=0.942
# epoch:7, batch:28. Loss=1.101
# epoch:7, batch:29. Loss=1.188
# epoch:7, batch:30. Loss=0.911
# epoch:7, batch:31. Loss=0.972
# epoch:7, batch:32. Loss=0.999
# epoch:7, batch:33. Loss=0.962
# epoch:7, batch:34. Loss=1.176
# epoch:7, batch:35. Loss=1.090
# epoch:7, batch:36. Loss=1.058
# epoch:7, batch:37. Loss=1.014
# epoch:7, batch:38. Loss=1.170
# epoch:7, batch:39. Loss=1.045
# epoch:7, batch:40. Loss=1.076
# epoch:7, batch:41. Loss=0.946
# epoch:7, batch:42. Loss=1.230
# epoch:7, batch:43. Loss=0.885
# epoch:7, batch:44. Loss=1.157
# epoch:7, batch:45. Loss=0.952
# epoch:7, batch:46. Loss=1.076
# epoch:7, batch:47. Loss=0.967
# epoch:7, batch:48. Loss=1.004
# epoch:7, batch:49. Loss=1.041
# epoch:7, batch:50. Loss=1.071
# epoch:7, batch:51. Loss=1.236
# epoch:7, batch:52. Loss=1.081
# epoch:7, batch:53. Loss=1.061
# epoch:7, batch:54. Loss=1.132
# epoch:7, batch:55. Loss=1.011
# epoch:7, batch:56. Loss=0.920
# epoch:7, batch:57. Loss=0.977
# epoch:7, batch:58. Loss=1.102
# epoch:7, batch:59. Loss=0.907
# epoch:7, batch:60. Loss=1.161
# epoch:7, batch:61. Loss=1.143
# epoch:7, batch:62. Loss=1.020
# epoch:7, batch:63. Loss=0.999
# epoch:7, batch:64. Loss=0.977
# epoch:7, batch:65. Loss=0.979
# epoch:7, batch:66. Loss=1.011
# epoch:7, batch:67. Loss=1.014
# epoch:7, batch:68. Loss=0.871
# epoch:7, batch:69. Loss=1.072
# epoch:7, batch:70. Loss=0.934
# epoch:7, batch:71. Loss=1.087
# epoch:7, batch:72. Loss=0.969
# epoch:7, batch:73. Loss=1.025
# epoch:7, batch:74. Loss=1.008
# epoch:7, batch:75. Loss=1.091
# epoch:7, batch:76. Loss=1.231
# epoch:7, batch:77. Loss=0.940
# epoch:7, batch:78. Loss=0.929
# epoch:7, batch:79. Loss=0.924
# epoch:7, batch:80. Loss=1.026
# epoch:7, batch:81. Loss=1.057
# epoch:7, batch:82. Loss=1.023
# epoch:7, batch:83. Loss=1.034
# epoch:7, batch:84. Loss=0.969
# epoch:7, batch:85. Loss=1.021
# epoch:7, batch:86. Loss=0.956
# epoch:7, batch:87. Loss=0.874
# epoch:7, batch:88. Loss=0.986
# epoch:7, batch:89. Loss=0.995
# epoch:7, batch:90. Loss=0.840
# epoch:7, batch:91. Loss=0.982
# epoch:7, batch:92. Loss=0.957
# epoch:7, batch:93. Loss=1.050
# epoch:7, batch:94. Loss=0.962
# epoch:7, batch:95. Loss=1.109
# epoch:7, batch:96. Loss=0.966
# epoch:7, batch:97. Loss=1.089
# epoch:7, batch:98. Loss=0.952
# epoch:7, batch:99. Loss=1.032
# epoch:7, batch:100. Loss=1.034
# epoch:7, batch:101. Loss=0.964
# epoch:7, batch:102. Loss=0.992
# epoch:7, batch:103. Loss=0.974
# epoch:7, batch:104. Loss=0.964
# epoch:7, batch:105. Loss=0.991
# epoch:7, batch:106. Loss=1.096
# epoch:7, batch:107. Loss=0.985
# epoch:7, batch:108. Loss=0.934
# epoch:7, batch:109. Loss=1.069
# epoch:7, batch:110. Loss=0.925
# epoch:7, batch:111. Loss=1.013
# epoch:7, batch:112. Loss=1.037
# epoch:7, batch:113. Loss=1.090
# epoch:7, batch:114. Loss=0.976
# epoch:7, batch:115. Loss=0.907
# epoch:7, batch:116. Loss=1.053
# epoch:7, batch:117. Loss=0.952
# epoch:7, batch:118. Loss=0.965
# epoch:7, batch:119. Loss=1.127
# epoch:7, batch:120. Loss=0.962
# epoch:7, batch:121. Loss=1.031
# epoch:7, batch:122. Loss=0.997
# epoch:7, batch:123. Loss=1.034
# epoch:7, batch:124. Loss=1.087
# epoch:7, batch:125. Loss=1.039
# epoch:7, batch:126. Loss=0.956
# epoch:7, batch:127. Loss=0.923
# epoch:7, batch:128. Loss=1.024
# epoch:7, batch:129. Loss=1.101
# epoch:7, batch:130. Loss=0.903
# epoch:7, batch:131. Loss=1.113
# epoch:7, batch:132. Loss=1.047
# epoch:7, batch:133. Loss=0.930
# epoch:7, batch:134. Loss=0.952
# epoch:7, batch:135. Loss=1.050
# epoch:7, batch:136. Loss=0.927
# epoch:7, batch:137. Loss=1.084
# epoch:7, batch:138. Loss=0.968
# epoch:7, batch:139. Loss=1.113
# epoch:7, batch:140. Loss=0.982
# epoch:7, batch:141. Loss=0.947
# epoch:7, batch:142. Loss=1.037
# epoch:7, batch:143. Loss=1.090
# epoch:7, batch:144. Loss=0.967
# epoch:7, batch:145. Loss=1.108
# epoch:7, batch:146. Loss=1.000
# epoch:7, batch:147. Loss=1.015
# epoch:7, batch:148. Loss=1.095
# epoch:7, batch:149. Loss=0.983
# epoch:7, batch:150. Loss=1.078
# epoch:7, batch:151. Loss=1.071
# epoch:7, batch:152. Loss=0.932
# epoch:7, batch:153. Loss=0.986
# epoch:7, batch:154. Loss=1.165
# epoch:7, batch:155. Loss=1.142
# epoch:7, batch:156. Loss=1.133
# epoch:7 over, training_acc=0.639, 'valid_acc=0.611
# epoch:8, batch:0. Loss=1.074
# epoch:8, batch:1. Loss=1.091
# epoch:8, batch:2. Loss=0.987
# epoch:8, batch:3. Loss=1.043
# epoch:8, batch:4. Loss=1.088
# epoch:8, batch:5. Loss=0.990
# epoch:8, batch:6. Loss=0.906
# epoch:8, batch:7. Loss=1.025
# epoch:8, batch:8. Loss=0.888
# epoch:8, batch:9. Loss=1.083
# epoch:8, batch:10. Loss=1.052
# epoch:8, batch:11. Loss=1.076
# epoch:8, batch:12. Loss=1.124
# epoch:8, batch:13. Loss=1.024
# epoch:8, batch:14. Loss=1.106
# epoch:8, batch:15. Loss=1.166
# epoch:8, batch:16. Loss=1.062
# epoch:8, batch:17. Loss=0.976
# epoch:8, batch:18. Loss=1.055
# epoch:8, batch:19. Loss=0.925
# epoch:8, batch:20. Loss=1.061
# epoch:8, batch:21. Loss=1.015
# epoch:8, batch:22. Loss=0.997
# epoch:8, batch:23. Loss=0.973
# epoch:8, batch:24. Loss=0.940
# epoch:8, batch:25. Loss=1.017
# epoch:8, batch:26. Loss=0.872
# epoch:8, batch:27. Loss=0.877
# epoch:8, batch:28. Loss=1.164
# epoch:8, batch:29. Loss=0.879
# epoch:8, batch:30. Loss=1.022
# epoch:8, batch:31. Loss=0.935
# epoch:8, batch:32. Loss=0.836
# epoch:8, batch:33. Loss=0.934
# epoch:8, batch:34. Loss=0.882
# epoch:8, batch:35. Loss=0.990
# epoch:8, batch:36. Loss=0.994
# epoch:8, batch:37. Loss=0.908
# epoch:8, batch:38. Loss=1.118
# epoch:8, batch:39. Loss=0.924
# epoch:8, batch:40. Loss=1.018
# epoch:8, batch:41. Loss=1.081
# epoch:8, batch:42. Loss=1.031
# epoch:8, batch:43. Loss=1.045
# epoch:8, batch:44. Loss=1.047
# epoch:8, batch:45. Loss=1.007
# epoch:8, batch:46. Loss=0.909
# epoch:8, batch:47. Loss=0.853
# epoch:8, batch:48. Loss=0.954
# epoch:8, batch:49. Loss=1.113
# epoch:8, batch:50. Loss=0.930
# epoch:8, batch:51. Loss=1.074
# epoch:8, batch:52. Loss=1.041
# epoch:8, batch:53. Loss=1.013
# epoch:8, batch:54. Loss=1.150
# epoch:8, batch:55. Loss=1.012
# epoch:8, batch:56. Loss=1.106
# epoch:8, batch:57. Loss=1.161
# epoch:8, batch:58. Loss=1.091
# epoch:8, batch:59. Loss=0.915
# epoch:8, batch:60. Loss=1.089
# epoch:8, batch:61. Loss=1.091
# epoch:8, batch:62. Loss=1.248
# epoch:8, batch:63. Loss=1.004
# epoch:8, batch:64. Loss=0.924
# epoch:8, batch:65. Loss=1.011
# epoch:8, batch:66. Loss=1.019
# epoch:8, batch:67. Loss=1.117
# epoch:8, batch:68. Loss=1.055
# epoch:8, batch:69. Loss=0.944
# epoch:8, batch:70. Loss=1.103
# epoch:8, batch:71. Loss=1.001
# epoch:8, batch:72. Loss=0.986
# epoch:8, batch:73. Loss=0.992
# epoch:8, batch:74. Loss=1.154
# epoch:8, batch:75. Loss=0.962
# epoch:8, batch:76. Loss=1.026
# epoch:8, batch:77. Loss=1.033
# epoch:8, batch:78. Loss=1.157
# epoch:8, batch:79. Loss=1.013
# epoch:8, batch:80. Loss=1.038
# epoch:8, batch:81. Loss=1.024
# epoch:8, batch:82. Loss=1.110
# epoch:8, batch:83. Loss=1.033
# epoch:8, batch:84. Loss=1.033
# epoch:8, batch:85. Loss=0.984
# epoch:8, batch:86. Loss=1.135
# epoch:8, batch:87. Loss=0.963
# epoch:8, batch:88. Loss=0.987
# epoch:8, batch:89. Loss=1.200
# epoch:8, batch:90. Loss=0.991
# epoch:8, batch:91. Loss=0.934
# epoch:8, batch:92. Loss=1.065
# epoch:8, batch:93. Loss=1.045
# epoch:8, batch:94. Loss=1.020
# epoch:8, batch:95. Loss=1.051
# epoch:8, batch:96. Loss=0.927
# epoch:8, batch:97. Loss=1.007
# epoch:8, batch:98. Loss=1.070
# epoch:8, batch:99. Loss=0.957
# epoch:8, batch:100. Loss=1.132
# epoch:8, batch:101. Loss=1.070
# epoch:8, batch:102. Loss=1.014
# epoch:8, batch:103. Loss=0.992
# epoch:8, batch:104. Loss=0.960
# epoch:8, batch:105. Loss=1.196
# epoch:8, batch:106. Loss=1.149
# epoch:8, batch:107. Loss=1.043
# epoch:8, batch:108. Loss=1.107
# epoch:8, batch:109. Loss=1.142
# epoch:8, batch:110. Loss=1.020
# epoch:8, batch:111. Loss=1.121
# epoch:8, batch:112. Loss=1.035
# epoch:8, batch:113. Loss=0.955
# epoch:8, batch:114. Loss=1.045
# epoch:8, batch:115. Loss=1.185
# epoch:8, batch:116. Loss=0.963
# epoch:8, batch:117. Loss=1.039
# epoch:8, batch:118. Loss=0.990
# epoch:8, batch:119. Loss=0.972
# epoch:8, batch:120. Loss=1.072
# epoch:8, batch:121. Loss=1.035
# epoch:8, batch:122. Loss=0.806
# epoch:8, batch:123. Loss=0.908
# epoch:8, batch:124. Loss=0.921
# epoch:8, batch:125. Loss=1.071
# epoch:8, batch:126. Loss=1.016
# epoch:8, batch:127. Loss=0.935
# epoch:8, batch:128. Loss=0.881
# epoch:8, batch:129. Loss=0.873
# epoch:8, batch:130. Loss=0.855
# epoch:8, batch:131. Loss=0.890
# epoch:8, batch:132. Loss=1.005
# epoch:8, batch:133. Loss=1.019
# epoch:8, batch:134. Loss=0.932
# epoch:8, batch:135. Loss=1.041
# epoch:8, batch:136. Loss=1.043
# epoch:8, batch:137. Loss=0.950
# epoch:8, batch:138. Loss=0.942
# epoch:8, batch:139. Loss=1.048
# epoch:8, batch:140. Loss=0.969
# epoch:8, batch:141. Loss=1.122
# epoch:8, batch:142. Loss=1.101
# epoch:8, batch:143. Loss=1.075
# epoch:8, batch:144. Loss=1.119
# epoch:8, batch:145. Loss=1.028
# epoch:8, batch:146. Loss=1.077
# epoch:8, batch:147. Loss=1.040
# epoch:8, batch:148. Loss=1.191
# epoch:8, batch:149. Loss=1.032
# epoch:8, batch:150. Loss=1.048
# epoch:8, batch:151. Loss=1.274
# epoch:8, batch:152. Loss=1.154
# epoch:8, batch:153. Loss=1.056
# epoch:8, batch:154. Loss=1.200
# epoch:8, batch:155. Loss=1.155
# epoch:8, batch:156. Loss=0.956
# epoch:8 over, training_acc=0.639, 'valid_acc=0.610
# epoch:9, batch:0. Loss=1.078
# epoch:9, batch:1. Loss=0.966
# epoch:9, batch:2. Loss=1.102
# epoch:9, batch:3. Loss=1.121
# epoch:9, batch:4. Loss=1.028
# epoch:9, batch:5. Loss=0.884
# epoch:9, batch:6. Loss=1.180
# epoch:9, batch:7. Loss=0.970
# epoch:9, batch:8. Loss=1.145
# epoch:9, batch:9. Loss=1.039
# epoch:9, batch:10. Loss=1.008
# epoch:9, batch:11. Loss=0.895
# epoch:9, batch:12. Loss=0.964
# epoch:9, batch:13. Loss=1.018
# epoch:9, batch:14. Loss=0.949
# epoch:9, batch:15. Loss=1.095
# epoch:9, batch:16. Loss=1.027
# epoch:9, batch:17. Loss=0.998
# epoch:9, batch:18. Loss=0.992
# epoch:9, batch:19. Loss=0.889
# epoch:9, batch:20. Loss=0.998
# epoch:9, batch:21. Loss=1.002
# epoch:9, batch:22. Loss=0.877
# epoch:9, batch:23. Loss=0.996
# epoch:9, batch:24. Loss=1.026
# epoch:9, batch:25. Loss=0.978
# epoch:9, batch:26. Loss=1.084
# epoch:9, batch:27. Loss=0.998
# epoch:9, batch:28. Loss=1.078
# epoch:9, batch:29. Loss=0.965
# epoch:9, batch:30. Loss=1.016
# epoch:9, batch:31. Loss=1.019
# epoch:9, batch:32. Loss=0.954
# epoch:9, batch:33. Loss=1.155
# epoch:9, batch:34. Loss=1.047
# epoch:9, batch:35. Loss=0.869
# epoch:9, batch:36. Loss=0.888
# epoch:9, batch:37. Loss=1.053
# epoch:9, batch:38. Loss=0.907
# epoch:9, batch:39. Loss=1.028
# epoch:9, batch:40. Loss=1.200
# epoch:9, batch:41. Loss=1.003
# epoch:9, batch:42. Loss=0.946
# epoch:9, batch:43. Loss=0.978
# epoch:9, batch:44. Loss=0.915
# epoch:9, batch:45. Loss=0.969
# epoch:9, batch:46. Loss=0.958
# epoch:9, batch:47. Loss=0.982
# epoch:9, batch:48. Loss=0.913
# epoch:9, batch:49. Loss=0.789
# epoch:9, batch:50. Loss=1.076
# epoch:9, batch:51. Loss=0.953
# epoch:9, batch:52. Loss=0.863
# epoch:9, batch:53. Loss=1.051
# epoch:9, batch:54. Loss=1.057
# epoch:9, batch:55. Loss=0.890
# epoch:9, batch:56. Loss=1.054
# epoch:9, batch:57. Loss=1.026
# epoch:9, batch:58. Loss=1.060
# epoch:9, batch:59. Loss=1.092
# epoch:9, batch:60. Loss=1.109
# epoch:9, batch:61. Loss=0.926
# epoch:9, batch:62. Loss=1.035
# epoch:9, batch:63. Loss=0.955
# epoch:9, batch:64. Loss=0.986
# epoch:9, batch:65. Loss=1.064
# epoch:9, batch:66. Loss=1.084
# epoch:9, batch:67. Loss=1.027
# epoch:9, batch:68. Loss=0.900
# epoch:9, batch:69. Loss=0.991
# epoch:9, batch:70. Loss=0.981
# epoch:9, batch:71. Loss=1.010
# epoch:9, batch:72. Loss=1.023
# epoch:9, batch:73. Loss=1.063
# epoch:9, batch:74. Loss=0.970
# epoch:9, batch:75. Loss=1.074
# epoch:9, batch:76. Loss=0.953
# epoch:9, batch:77. Loss=1.081
# epoch:9, batch:78. Loss=1.126
# epoch:9, batch:79. Loss=1.038
# epoch:9, batch:80. Loss=1.081
# epoch:9, batch:81. Loss=1.087
# epoch:9, batch:82. Loss=0.868
# epoch:9, batch:83. Loss=0.961
# epoch:9, batch:84. Loss=1.112
# epoch:9, batch:85. Loss=0.949
# epoch:9, batch:86. Loss=0.968
# epoch:9, batch:87. Loss=1.070
# epoch:9, batch:88. Loss=1.151
# epoch:9, batch:89. Loss=1.093
# epoch:9, batch:90. Loss=0.924
# epoch:9, batch:91. Loss=0.948
# epoch:9, batch:92. Loss=1.014
# epoch:9, batch:93. Loss=0.940
# epoch:9, batch:94. Loss=1.061
# epoch:9, batch:95. Loss=1.067
# epoch:9, batch:96. Loss=1.105
# epoch:9, batch:97. Loss=0.986
# epoch:9, batch:98. Loss=0.995
# epoch:9, batch:99. Loss=1.121
# epoch:9, batch:100. Loss=0.972
# epoch:9, batch:101. Loss=0.940
# epoch:9, batch:102. Loss=0.861
# epoch:9, batch:103. Loss=0.991
# epoch:9, batch:104. Loss=1.002
# epoch:9, batch:105. Loss=0.974
# epoch:9, batch:106. Loss=1.009
# epoch:9, batch:107. Loss=0.973
# epoch:9, batch:108. Loss=0.920
# epoch:9, batch:109. Loss=1.044
# epoch:9, batch:110. Loss=0.955
# epoch:9, batch:111. Loss=1.164
# epoch:9, batch:112. Loss=1.056
# epoch:9, batch:113. Loss=0.902
# epoch:9, batch:114. Loss=0.897
# epoch:9, batch:115. Loss=1.129
# epoch:9, batch:116. Loss=0.930
# epoch:9, batch:117. Loss=0.985
# epoch:9, batch:118. Loss=1.079
# epoch:9, batch:119. Loss=0.877
# epoch:9, batch:120. Loss=1.007
# epoch:9, batch:121. Loss=1.084
# epoch:9, batch:122. Loss=0.981
# epoch:9, batch:123. Loss=1.002
# epoch:9, batch:124. Loss=1.048
# epoch:9, batch:125. Loss=0.914
# epoch:9, batch:126. Loss=0.957
# epoch:9, batch:127. Loss=0.848
# epoch:9, batch:128. Loss=1.012
# epoch:9, batch:129. Loss=0.932
# epoch:9, batch:130. Loss=1.182
# epoch:9, batch:131. Loss=1.079
# epoch:9, batch:132. Loss=1.138
# epoch:9, batch:133. Loss=0.993
# epoch:9, batch:134. Loss=0.980
# epoch:9, batch:135. Loss=0.984
# epoch:9, batch:136. Loss=1.019
# epoch:9, batch:137. Loss=0.962
# epoch:9, batch:138. Loss=0.958
# epoch:9, batch:139. Loss=1.011
# epoch:9, batch:140. Loss=1.011
# epoch:9, batch:141. Loss=0.796
# epoch:9, batch:142. Loss=0.982
# epoch:9, batch:143. Loss=0.979
# epoch:9, batch:144. Loss=1.031
# epoch:9, batch:145. Loss=1.015
# epoch:9, batch:146. Loss=0.997
# epoch:9, batch:147. Loss=1.011
# epoch:9, batch:148. Loss=0.894
# epoch:9, batch:149. Loss=1.022
# epoch:9, batch:150. Loss=0.925
# epoch:9, batch:151. Loss=1.016
# epoch:9, batch:152. Loss=1.039
# epoch:9, batch:153. Loss=1.065
# epoch:9, batch:154. Loss=0.948
# epoch:9, batch:155. Loss=1.009
# ...
# epoch:46, batch:125. Loss=0.661
# epoch:46, batch:126. Loss=0.622
# epoch:46, batch:127. Loss=0.622
# epoch:46, batch:128. Loss=0.628
# epoch:46, batch:129. Loss=0.615
# epoch:46, batch:130. Loss=0.607
# epoch:46, batch:131. Loss=0.623
# epoch:46, batch:132. Loss=0.676
# epoch:46, batch:133. Loss=0.522
# epoch:46, batch:134. Loss=0.622
# epoch:46, batch:135. Loss=0.684
# epoch:46, batch:136. Loss=0.621
# epoch:46, batch:137. Loss=0.679
# epoch:46, batch:138. Loss=0.686
# epoch:46, batch:139. Loss=0.522
# epoch:46, batch:140. Loss=0.678
# epoch:46, batch:141. Loss=0.522
# epoch:46, batch:142. Loss=0.579
# epoch:46, batch:143. Loss=0.573
# epoch:46, batch:144. Loss=0.664
# epoch:46, batch:145. Loss=0.694
# epoch:46, batch:146. Loss=0.593
# epoch:46, batch:147. Loss=0.632
# epoch:46, batch:148. Loss=0.599
# epoch:46, batch:149. Loss=0.597
# epoch:46, batch:150. Loss=0.559
# epoch:46, batch:151. Loss=0.717
# epoch:46, batch:152. Loss=0.763
# epoch:46, batch:153. Loss=0.682
# epoch:46, batch:154. Loss=0.684
# epoch:46, batch:155. Loss=0.603
# epoch:46, batch:156. Loss=0.803
# epoch:46 over, training_acc=0.777, 'valid_acc=0.723
# epoch:47, batch:0. Loss=0.623
# epoch:47, batch:1. Loss=0.636
# epoch:47, batch:2. Loss=0.659
# epoch:47, batch:3. Loss=0.821
# epoch:47, batch:4. Loss=0.667
# epoch:47, batch:5. Loss=0.612
# epoch:47, batch:6. Loss=0.624
# epoch:47, batch:7. Loss=0.634
# epoch:47, batch:8. Loss=0.552
# epoch:47, batch:9. Loss=0.712
# epoch:47, batch:10. Loss=0.766
# epoch:47, batch:11. Loss=0.539
# epoch:47, batch:12. Loss=0.658
# epoch:47, batch:13. Loss=0.660
# epoch:47, batch:14. Loss=0.607
# epoch:47, batch:15. Loss=0.661
# epoch:47, batch:16. Loss=0.564
# epoch:47, batch:17. Loss=0.701
# epoch:47, batch:18. Loss=0.664
# epoch:47, batch:19. Loss=0.664
# epoch:47, batch:20. Loss=0.637
# epoch:47, batch:21. Loss=0.691
# epoch:47, batch:22. Loss=0.651
# epoch:47, batch:23. Loss=0.596
# epoch:47, batch:24. Loss=0.567
# epoch:47, batch:25. Loss=0.747
# epoch:47, batch:26. Loss=0.614
# epoch:47, batch:27. Loss=0.610
# epoch:47, batch:28. Loss=0.665
# epoch:47, batch:29. Loss=0.682
# epoch:47, batch:30. Loss=0.683
# epoch:47, batch:31. Loss=0.666
# epoch:47, batch:32. Loss=0.672
# epoch:47, batch:33. Loss=0.565
# epoch:47, batch:34. Loss=0.555
# epoch:47, batch:35. Loss=0.598
# epoch:47, batch:36. Loss=0.651
# epoch:47, batch:37. Loss=0.629
# epoch:47, batch:38. Loss=0.612
# epoch:47, batch:39. Loss=0.652
# epoch:47, batch:40. Loss=0.576
# epoch:47, batch:41. Loss=0.635
# epoch:47, batch:42. Loss=0.692
# epoch:47, batch:43. Loss=0.715
# epoch:47, batch:44. Loss=0.656
# epoch:47, batch:45. Loss=0.643
# epoch:47, batch:46. Loss=0.730
# epoch:47, batch:47. Loss=0.632
# epoch:47, batch:48. Loss=0.699
# epoch:47, batch:49. Loss=0.609
# epoch:47, batch:50. Loss=0.570
# epoch:47, batch:51. Loss=0.548
# epoch:47, batch:52. Loss=0.577
# epoch:47, batch:53. Loss=0.704
# epoch:47, batch:54. Loss=0.644
# epoch:47, batch:55. Loss=0.643
# epoch:47, batch:56. Loss=0.700
# epoch:47, batch:57. Loss=0.655
# epoch:47, batch:58. Loss=0.696
# epoch:47, batch:59. Loss=0.498
# epoch:47, batch:60. Loss=0.618
# epoch:47, batch:61. Loss=0.675
# epoch:47, batch:62. Loss=0.580
# epoch:47, batch:63. Loss=0.660
# epoch:47, batch:64. Loss=0.585
# epoch:47, batch:65. Loss=0.656
# epoch:47, batch:66. Loss=0.599
# epoch:47, batch:67. Loss=0.538
# epoch:47, batch:68. Loss=0.645
# epoch:47, batch:69. Loss=0.648
# epoch:47, batch:70. Loss=0.632
# epoch:47, batch:71. Loss=0.643
# epoch:47, batch:72. Loss=0.593
# epoch:47, batch:73. Loss=0.738
# epoch:47, batch:74. Loss=0.733
# epoch:47, batch:75. Loss=0.703
# epoch:47, batch:76. Loss=0.660
# epoch:47, batch:77. Loss=0.667
# epoch:47, batch:78. Loss=0.607
# epoch:47, batch:79. Loss=0.735
# epoch:47, batch:80. Loss=0.685
# epoch:47, batch:81. Loss=0.583
# epoch:47, batch:82. Loss=0.691
# epoch:47, batch:83. Loss=0.557
# epoch:47, batch:84. Loss=0.636
# epoch:47, batch:85. Loss=0.593
# epoch:47, batch:86. Loss=0.583
# epoch:47, batch:87. Loss=0.716
# epoch:47, batch:88. Loss=0.623
# epoch:47, batch:89. Loss=0.600
# epoch:47, batch:90. Loss=0.728
# epoch:47, batch:91. Loss=0.621
# epoch:47, batch:92. Loss=0.738
# epoch:47, batch:93. Loss=0.550
# epoch:47, batch:94. Loss=0.583
# epoch:47, batch:95. Loss=0.570
# epoch:47, batch:96. Loss=0.579
# epoch:47, batch:97. Loss=0.624
# epoch:47, batch:98. Loss=0.642
# epoch:47, batch:99. Loss=0.562
# epoch:47, batch:100. Loss=0.690
# epoch:47, batch:101. Loss=0.604
# epoch:47, batch:102. Loss=0.613
# epoch:47, batch:103. Loss=0.635
# epoch:47, batch:104. Loss=0.694
# epoch:47, batch:105. Loss=0.683
# epoch:47, batch:106. Loss=0.539
# epoch:47, batch:107. Loss=0.653
# epoch:47, batch:108. Loss=0.662
# epoch:47, batch:109. Loss=0.695
# epoch:47, batch:110. Loss=0.522
# epoch:47, batch:111. Loss=0.630
# epoch:47, batch:112. Loss=0.763
# epoch:47, batch:113. Loss=0.656
# epoch:47, batch:114. Loss=0.687
# epoch:47, batch:115. Loss=0.800
# epoch:47, batch:116. Loss=0.641
# epoch:47, batch:117. Loss=0.625
# epoch:47, batch:118. Loss=0.566
# epoch:47, batch:119. Loss=0.763
# epoch:47, batch:120. Loss=0.644
# epoch:47, batch:121. Loss=0.570
# epoch:47, batch:122. Loss=0.612
# epoch:47, batch:123. Loss=0.615
# epoch:47, batch:124. Loss=0.664
# epoch:47, batch:125. Loss=0.783
# epoch:47, batch:126. Loss=0.549
# epoch:47, batch:127. Loss=0.643
# epoch:47, batch:128. Loss=0.633
# epoch:47, batch:129. Loss=0.713
# epoch:47, batch:130. Loss=0.623
# epoch:47, batch:131. Loss=0.711
# epoch:47, batch:132. Loss=0.628
# epoch:47, batch:133. Loss=0.625
# epoch:47, batch:134. Loss=0.584
# epoch:47, batch:135. Loss=0.665
# epoch:47, batch:136. Loss=0.689
# epoch:47, batch:137. Loss=0.593
# epoch:47, batch:138. Loss=0.754
# epoch:47, batch:139. Loss=0.684
# epoch:47, batch:140. Loss=0.493
# epoch:47, batch:141. Loss=0.543
# epoch:47, batch:142. Loss=0.773
# epoch:47, batch:143. Loss=0.597
# epoch:47, batch:144. Loss=0.632
# epoch:47, batch:145. Loss=0.691
# epoch:47, batch:146. Loss=0.617
# epoch:47, batch:147. Loss=0.589
# epoch:47, batch:148. Loss=0.626
# epoch:47, batch:149. Loss=0.579
# epoch:47, batch:150. Loss=0.567
# epoch:47, batch:151. Loss=0.623
# epoch:47, batch:152. Loss=0.612
# epoch:47, batch:153. Loss=0.628
# epoch:47, batch:154. Loss=0.558
# epoch:47, batch:155. Loss=0.730
# epoch:47, batch:156. Loss=1.021
# epoch:47 over, training_acc=0.773, 'valid_acc=0.727
# epoch:48, batch:0. Loss=0.616
# epoch:48, batch:1. Loss=0.671
# epoch:48, batch:2. Loss=0.605
# epoch:48, batch:3. Loss=0.704
# epoch:48, batch:4. Loss=0.594
# epoch:48, batch:5. Loss=0.734
# epoch:48, batch:6. Loss=0.690
# epoch:48, batch:7. Loss=0.678
# epoch:48, batch:8. Loss=0.684
# epoch:48, batch:9. Loss=0.609
# epoch:48, batch:10. Loss=0.695
# epoch:48, batch:11. Loss=0.596
# epoch:48, batch:12. Loss=0.616
# epoch:48, batch:13. Loss=0.529
# epoch:48, batch:14. Loss=0.798
# epoch:48, batch:15. Loss=0.542
# epoch:48, batch:16. Loss=0.679
# epoch:48, batch:17. Loss=0.617
# epoch:48, batch:18. Loss=0.632
# epoch:48, batch:19. Loss=0.639
# epoch:48, batch:20. Loss=0.580
# epoch:48, batch:21. Loss=0.697
# epoch:48, batch:22. Loss=0.657
# epoch:48, batch:23. Loss=0.694
# epoch:48, batch:24. Loss=0.586
# epoch:48, batch:25. Loss=0.552
# epoch:48, batch:26. Loss=0.541
# epoch:48, batch:27. Loss=0.587
# epoch:48, batch:28. Loss=0.515
# epoch:48, batch:29. Loss=0.614
# epoch:48, batch:30. Loss=0.602
# epoch:48, batch:31. Loss=0.663
# epoch:48, batch:32. Loss=0.505
# epoch:48, batch:33. Loss=0.558
# epoch:48, batch:34. Loss=0.674
# epoch:48, batch:35. Loss=0.650
# epoch:48, batch:36. Loss=0.577
# epoch:48, batch:37. Loss=0.630
# epoch:48, batch:38. Loss=0.657
# epoch:48, batch:39. Loss=0.678
# epoch:48, batch:40. Loss=0.716
# epoch:48, batch:41. Loss=0.535
# epoch:48, batch:42. Loss=0.695
# epoch:48, batch:43. Loss=0.690
# epoch:48, batch:44. Loss=0.448
# epoch:48, batch:45. Loss=0.688
# epoch:48, batch:46. Loss=0.731
# epoch:48, batch:47. Loss=0.592
# epoch:48, batch:48. Loss=0.663
# epoch:48, batch:49. Loss=0.627
# epoch:48, batch:50. Loss=0.566
# epoch:48, batch:51. Loss=0.691
# epoch:48, batch:52. Loss=0.775
# epoch:48, batch:53. Loss=0.598
# epoch:48, batch:54. Loss=0.611
# epoch:48, batch:55. Loss=0.684
# epoch:48, batch:56. Loss=0.696
# epoch:48, batch:57. Loss=0.576
# epoch:48, batch:58. Loss=0.644
# epoch:48, batch:59. Loss=0.685
# epoch:48, batch:60. Loss=0.651
# epoch:48, batch:61. Loss=0.581
# epoch:48, batch:62. Loss=0.584
# epoch:48, batch:63. Loss=0.559
# epoch:48, batch:64. Loss=0.608
# epoch:48, batch:65. Loss=0.661
# epoch:48, batch:66. Loss=0.572
# epoch:48, batch:67. Loss=0.627
# epoch:48, batch:68. Loss=0.689
# epoch:48, batch:69. Loss=0.577
# epoch:48, batch:70. Loss=0.597
# epoch:48, batch:71. Loss=0.746
# epoch:48, batch:72. Loss=0.534
# epoch:48, batch:73. Loss=0.607
# epoch:48, batch:74. Loss=0.620
# epoch:48, batch:75. Loss=0.595
# epoch:48, batch:76. Loss=0.565
# epoch:48, batch:77. Loss=0.673
# epoch:48, batch:78. Loss=0.612
# epoch:48, batch:79. Loss=0.641
# epoch:48, batch:80. Loss=0.706
# epoch:48, batch:81. Loss=0.803
# epoch:48, batch:82. Loss=0.642
# epoch:48, batch:83. Loss=0.625
# epoch:48, batch:84. Loss=0.572
# epoch:48, batch:85. Loss=0.591
# epoch:48, batch:86. Loss=0.550
# epoch:48, batch:87. Loss=0.711
# epoch:48, batch:88. Loss=0.849
# epoch:48, batch:89. Loss=0.566
# epoch:48, batch:90. Loss=0.666
# epoch:48, batch:91. Loss=0.672
# epoch:48, batch:92. Loss=0.699
# epoch:48, batch:93. Loss=0.742
# epoch:48, batch:94. Loss=0.644
# epoch:48, batch:95. Loss=0.549
# epoch:48, batch:96. Loss=0.589
# epoch:48, batch:97. Loss=0.743
# epoch:48, batch:98. Loss=0.615
# epoch:48, batch:99. Loss=0.589
# epoch:48, batch:100. Loss=0.596
# epoch:48, batch:101. Loss=0.565
# epoch:48, batch:102. Loss=0.687
# epoch:48, batch:103. Loss=0.735
# epoch:48, batch:104. Loss=0.634
# epoch:48, batch:105. Loss=0.769
# epoch:48, batch:106. Loss=0.712
# epoch:48, batch:107. Loss=0.698
# epoch:48, batch:108. Loss=0.618
# epoch:48, batch:109. Loss=0.668
# epoch:48, batch:110. Loss=0.613
# epoch:48, batch:111. Loss=0.708
# epoch:48, batch:112. Loss=0.533
# epoch:48, batch:113. Loss=0.667
# epoch:48, batch:114. Loss=0.583
# epoch:48, batch:115. Loss=0.733
# epoch:48, batch:116. Loss=0.573
# epoch:48, batch:117. Loss=0.709
# epoch:48, batch:118. Loss=0.778
# epoch:48, batch:119. Loss=0.666
# epoch:48, batch:120. Loss=0.666
# epoch:48, batch:121. Loss=0.585
# epoch:48, batch:122. Loss=0.624
# epoch:48, batch:123. Loss=0.676
# epoch:48, batch:124. Loss=0.649
# epoch:48, batch:125. Loss=0.605
# epoch:48, batch:126. Loss=0.740
# epoch:48, batch:127. Loss=0.624
# epoch:48, batch:128. Loss=0.596
# epoch:48, batch:129. Loss=0.536
# epoch:48, batch:130. Loss=0.614
# epoch:48, batch:131. Loss=0.654
# epoch:48, batch:132. Loss=0.664
# epoch:48, batch:133. Loss=0.665
# epoch:48, batch:134. Loss=0.637
# epoch:48, batch:135. Loss=0.619
# epoch:48, batch:136. Loss=0.595
# epoch:48, batch:137. Loss=0.727
# epoch:48, batch:138. Loss=0.776
# epoch:48, batch:139. Loss=0.611
# epoch:48, batch:140. Loss=0.595
# epoch:48, batch:141. Loss=0.629
# epoch:48, batch:142. Loss=0.648
# epoch:48, batch:143. Loss=0.626
# epoch:48, batch:144. Loss=0.561
# epoch:48, batch:145. Loss=0.665
# epoch:48, batch:146. Loss=0.622
# epoch:48, batch:147. Loss=0.542
# epoch:48, batch:148. Loss=0.566
# epoch:48, batch:149. Loss=0.628
# epoch:48, batch:150. Loss=0.675
# epoch:48, batch:151. Loss=0.627
# epoch:48, batch:152. Loss=0.613
# epoch:48, batch:153. Loss=0.758
# epoch:48, batch:154. Loss=0.630
# epoch:48, batch:155. Loss=0.719
# epoch:48, batch:156. Loss=0.726
# epoch:48 over, training_acc=0.775, 'valid_acc=0.729
# epoch:49, batch:0. Loss=0.714
# epoch:49, batch:1. Loss=0.661
# epoch:49, batch:2. Loss=0.608
# epoch:49, batch:3. Loss=0.724
# epoch:49, batch:4. Loss=0.575
# epoch:49, batch:5. Loss=0.595
# epoch:49, batch:6. Loss=0.642
# epoch:49, batch:7. Loss=0.565
# epoch:49, batch:8. Loss=0.617
# epoch:49, batch:9. Loss=0.657
# epoch:49, batch:10. Loss=0.509
# epoch:49, batch:11. Loss=0.586
# epoch:49, batch:12. Loss=0.643
# epoch:49, batch:13. Loss=0.623
# epoch:49, batch:14. Loss=0.669
# epoch:49, batch:15. Loss=0.660
# epoch:49, batch:16. Loss=0.602
# epoch:49, batch:17. Loss=0.600
# epoch:49, batch:18. Loss=0.621
# epoch:49, batch:19. Loss=0.573
# epoch:49, batch:20. Loss=0.756
# epoch:49, batch:21. Loss=0.575
# epoch:49, batch:22. Loss=0.743
# epoch:49, batch:23. Loss=0.648
# epoch:49, batch:24. Loss=0.610
# epoch:49, batch:25. Loss=0.525
# epoch:49, batch:26. Loss=0.603
# epoch:49, batch:27. Loss=0.643
# epoch:49, batch:28. Loss=0.559
# epoch:49, batch:29. Loss=0.772
# epoch:49, batch:30. Loss=0.740
# epoch:49, batch:31. Loss=0.658
# epoch:49, batch:32. Loss=0.666
# epoch:49, batch:33. Loss=0.756
# epoch:49, batch:34. Loss=0.602
# epoch:49, batch:35. Loss=0.583
# epoch:49, batch:36. Loss=0.628
# epoch:49, batch:37. Loss=0.655
# epoch:49, batch:38. Loss=0.715
# epoch:49, batch:39. Loss=0.734
# epoch:49, batch:40. Loss=0.648
# epoch:49, batch:41. Loss=0.634
# epoch:49, batch:42. Loss=0.661
# epoch:49, batch:43. Loss=0.640
# epoch:49, batch:44. Loss=0.619
# epoch:49, batch:45. Loss=0.691
# epoch:49, batch:46. Loss=0.566
# epoch:49, batch:47. Loss=0.629
# epoch:49, batch:48. Loss=0.577
# epoch:49, batch:49. Loss=0.612
# epoch:49, batch:50. Loss=0.537
# epoch:49, batch:51. Loss=0.641
# epoch:49, batch:52. Loss=0.658
# epoch:49, batch:53. Loss=0.585
# epoch:49, batch:54. Loss=0.606
# epoch:49, batch:55. Loss=0.616
# epoch:49, batch:56. Loss=0.684
# epoch:49, batch:57. Loss=0.587
# epoch:49, batch:58. Loss=0.599
# epoch:49, batch:59. Loss=0.737
# epoch:49, batch:60. Loss=0.729
# epoch:49, batch:61. Loss=0.526
# epoch:49, batch:62. Loss=0.562
# epoch:49, batch:63. Loss=0.656
# epoch:49, batch:64. Loss=0.601
# epoch:49, batch:65. Loss=0.722
# epoch:49, batch:66. Loss=0.594
# epoch:49, batch:67. Loss=0.718
# epoch:49, batch:68. Loss=0.659
# epoch:49, batch:69. Loss=0.553
# epoch:49, batch:70. Loss=0.627
# epoch:49, batch:71. Loss=0.617
# epoch:49, batch:72. Loss=0.597
# epoch:49, batch:73. Loss=0.719
# epoch:49, batch:74. Loss=0.673
# epoch:49, batch:75. Loss=0.581
# epoch:49, batch:76. Loss=0.556
# epoch:49, batch:77. Loss=0.720
# epoch:49, batch:78. Loss=0.651
# epoch:49, batch:79. Loss=0.613
# epoch:49, batch:80. Loss=0.686
# epoch:49, batch:81. Loss=0.806
# epoch:49, batch:82. Loss=0.680
# epoch:49, batch:83. Loss=0.638
# epoch:49, batch:84. Loss=0.584
# epoch:49, batch:85. Loss=0.578
# epoch:49, batch:86. Loss=0.619
# epoch:49, batch:87. Loss=0.517
# epoch:49, batch:88. Loss=0.662
# epoch:49, batch:89. Loss=0.594
# epoch:49, batch:90. Loss=0.772
# epoch:49, batch:91. Loss=0.566
# epoch:49, batch:92. Loss=0.581
# epoch:49, batch:93. Loss=0.651
# epoch:49, batch:94. Loss=0.728
# epoch:49, batch:95. Loss=0.710
# epoch:49, batch:96. Loss=0.534
# epoch:49, batch:97. Loss=0.658
# epoch:49, batch:98. Loss=0.707
# epoch:49, batch:99. Loss=0.604
# epoch:49, batch:100. Loss=0.540
# epoch:49, batch:101. Loss=0.568
# epoch:49, batch:102. Loss=0.534
# epoch:49, batch:103. Loss=0.601
# epoch:49, batch:104. Loss=0.567
# epoch:49, batch:105. Loss=0.802
# epoch:49, batch:106. Loss=0.646
# epoch:49, batch:107. Loss=0.701
# epoch:49, batch:108. Loss=0.648
# epoch:49, batch:109. Loss=0.729
# epoch:49, batch:110. Loss=0.645
# epoch:49, batch:111. Loss=0.550
# epoch:49, batch:112. Loss=0.623
# epoch:49, batch:113. Loss=0.647
# epoch:49, batch:114. Loss=0.666
# epoch:49, batch:115. Loss=0.661
# epoch:49, batch:116. Loss=0.694
# epoch:49, batch:117. Loss=0.625
# epoch:49, batch:118. Loss=0.502
# epoch:49, batch:119. Loss=0.667
# epoch:49, batch:120. Loss=0.621
# epoch:49, batch:121. Loss=0.633
# epoch:49, batch:122. Loss=0.652
# epoch:49, batch:123. Loss=0.631
# epoch:49, batch:124. Loss=0.608
# epoch:49, batch:125. Loss=0.679
# epoch:49, batch:126. Loss=0.716
# epoch:49, batch:127. Loss=0.573
# epoch:49, batch:128. Loss=0.633
# epoch:49, batch:129. Loss=0.609
# epoch:49, batch:130. Loss=0.668
# epoch:49, batch:131. Loss=0.630
# epoch:49, batch:132. Loss=0.519
# epoch:49, batch:133. Loss=0.590
# epoch:49, batch:134. Loss=0.627
# epoch:49, batch:135. Loss=0.679
# epoch:49, batch:136. Loss=0.566
# epoch:49, batch:137. Loss=0.545
# epoch:49, batch:138. Loss=0.620
# epoch:49, batch:139. Loss=0.651
# epoch:49, batch:140. Loss=0.695
# epoch:49, batch:141. Loss=0.623
# epoch:49, batch:142. Loss=0.630
# epoch:49, batch:143. Loss=0.701
# epoch:49, batch:144. Loss=0.787
# epoch:49, batch:145. Loss=0.716
# epoch:49, batch:146. Loss=0.624
# epoch:49, batch:147. Loss=0.601
# epoch:49, batch:148. Loss=0.733
# epoch:49, batch:149. Loss=0.613
# epoch:49, batch:150. Loss=0.648
# epoch:49, batch:151. Loss=0.619
# epoch:49, batch:152. Loss=0.652
# epoch:49, batch:153. Loss=0.565
# epoch:49, batch:154. Loss=0.589
# epoch:49, batch:155. Loss=0.665
# epoch:49, batch:156. Loss=0.622
# epoch:49 over, training_acc=0.775, 'valid_acc=0.727
